# %% [raw]
# Evaluation Project - 1
#
# Baseball Case Study
#
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\91964\Desktop\nazia\datascience\Projects_DT\baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [raw]
# Here
# W = no of wins number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work
#
# R= Runs scored: number of times a player crosses home plate
#
# AB= At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
#
# H = Hit: reaching base because of a batted, fair ball without error by the defense
#
# 2B= Double: hits on which the batter reaches second base safely without the contribution of a fielding error
#
# 3B= Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
#
# HR=At bats per home run: at bats divided by home runs
#
# BB=Base on balls(also called a "walk")hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# SO= Strikeout: number of batters who received strike three
#
# SB=Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
#
# RA=Run average: number of runs allowed times nine divided by innings pitched
#
# ER= Earned run: number of runs that did not occur as a result of errors or passed balls
#
# ERA=Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
#
# CG=Complete game: number of games where player was the only pitcher for their team
#
# SHO= Shutout: number of complete games pitched with no runs allowed
#
# SV=Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
#
# E= Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result
# To make it better understand we rename columns

# %%
df=df.rename(columns={'W':'wins',
                      'R':'RunScored', 
                      'AB':'At Bat', 
                      'H':'Hits', 
                      '2B':'Doubles', 
                      '3B':'Triples', 
                      'HR':'Home Run', 
                      'BB':'Base on Balls', 
                      'SO':'Strikeout', 
                      'SB':'Stolen Base', 
                      'RA':'Runs Average', 
                      'ER':'Earned Runs',
                      'ERA':'Earned Runs Average', 
                      'CG': 'Complete Game', 
                      'SHO':'Shot Out', 
                      'SV':'Save', 
                      'E':'Errors'
                  })
df.head()
# Out:
#    wins  RunScored  At Bat  Hits  Doubles  Triples  Home Run  Base on Balls  \
# 0    95        724    5575  1497      300       42       139            383
# 1    83        696    5467  1349      277       44       156            439
# 2    81        669    5439  1395      303       29       141            533
# 3    76        622    5533  1381      260       27       136            404
# 4    74        689    5605  1515      289       49       151            455
#
#    Strikeout  Stolen Base  Runs Average  Earned Runs  Earned Runs Average  \
# 0        973          104           641          601                 3.73
# 1       1264           70           700          653                 4.07
# 2       1157           86           640          584                 3.67
# 3       1231           68           701          643                 3.98
# 4       1259           83           803          746                 4.64
#
#    Complete Game  Shot Out  Save  Errors
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
# EDA Analysis

# %%
df.isna().sum()
# Out:
# wins                   0
# RunScored              0
# At Bat                 0
# Hits                   0
# Doubles                0
# Triples                0
# Home Run               0
# Base on Balls          0
# Strikeout              0
# Stolen Base            0
# Runs Average           0
# Earned Runs            0
# Earned Runs Average    0
# Complete Game          0
# Shot Out               0
# Save                   0
# Errors                 0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# wins                   0
# RunScored              0
# At Bat                 0
# Hits                   0
# Doubles                0
# Triples                0
# Home Run               0
# Base on Balls          0
# Strikeout              0
# Stolen Base            0
# Runs Average           0
# Earned Runs            0
# Earned Runs Average    0
# Complete Game          0
# Shot Out               0
# Save                   0
# Errors                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# # There is no null value present

# %%
df.dtypes
# Out:
# wins                     int64
# RunScored                int64
# At Bat                   int64
# Hits                     int64
# Doubles                  int64
# Triples                  int64
# Home Run                 int64
# Base on Balls            int64
# Strikeout                int64
# Stolen Base              int64
# Runs Average             int64
# Earned Runs              int64
# Earned Runs Average    float64
# Complete Game            int64
# Shot Out                 int64
# Save                     int64
# Errors                   int64
# dtype: object

# %% [raw]
# # All are integer type only ERA is float type

# %%
df.head()
# Out:
#    wins  RunScored  At Bat  Hits  Doubles  Triples  Home Run  Base on Balls  \
# 0    95        724    5575  1497      300       42       139            383
# 1    83        696    5467  1349      277       44       156            439
# 2    81        669    5439  1395      303       29       141            533
# 3    76        622    5533  1381      260       27       136            404
# 4    74        689    5605  1515      289       49       151            455
#
#    Strikeout  Stolen Base  Runs Average  Earned Runs  Earned Runs Average  \
# 0        973          104           641          601                 3.73
# 1       1264           70           700          653                 4.07
# 2       1157           86           640          584                 3.67
# 3       1231           68           701          643                 3.98
# 4       1259           83           803          746                 4.64
#
#    Complete Game  Shot Out  Save  Errors
# ...

# %%
df.describe()
# Out:
#              wins   RunScored       At Bat         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Home Run  Base on Balls   Strikeout  Stolen Base  \
# count  30.000000   30.000000      30.000000    30.00000    30.000000
# mean   31.300000  163.633333     469.100000  1248.20000    83.500000
# std    10.452355   31.823309      57.053725   103.75947    22.815225
# min    13.000000  100.000000     375.000000   973.00000    44.000000
# ...

# %% [raw]
# ## Total rows are 200 and total columns are 5
#
# 1.Win : Here it is our target variable min is 63 and max is 100.It is continuous data we can solved this problem by both
#       classification and regression
#
# 2.RunScored : Mean=688 ,std=58.7 ,min=573 , max=891
#
# 3.At Bat: Mean=5516 ,std=70.4 ,min=5385 , max=5649
#
# 4.Hits: Mean=1403 ,std=57 ,min=1324 , max=1515
#
# 5.Doubles :Mean=274 ,std=18 ,min=236 , max=308
#
# 6.Triples: Mean=31 ,std=10 ,min=13 , max=49
#
# 7.HomeRun :Mean=163 ,std=31.8 ,min=100 , max=232
#
# 8.Base on Ball: Mean=469 ,std=57 ,min=375 , max=570
#
# 9.Strikeout :Mean=1248 ,std=103 ,min=973 , max=1518
#
# 10.Stolen Base: Mean=83.5 ,std=22.8 ,min=44 , max=134
#
# 11.Runs Average :Mean=688 ,std=72 ,min=525 , max=844
#
# 12.Earned Runs :Mean=635 ,std=70 ,min=478 , max=799
#
# 13.Earned Runs Average: Mean=3.9 ,std=0.45 ,min=2.94 , max=5
#
# 14.Complete Game:Mean=3.4 ,std=2.7 ,min=3, max=11
#
# 15.Shot Out :Mean=11 ,std=4.1 ,min=4 , max=21
#
# 16.Save: Mean=43 ,std=7 ,min=28 , max=62
#
# 17.Errors :Mean=94 ,std=14 ,min=75 , max=126

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   wins                 30 non-null     int64
#  1   RunScored            30 non-null     int64
#  2   At Bat               30 non-null     int64
#  3   Hits                 30 non-null     int64
#  4   Doubles              30 non-null     int64
#  5   Triples              30 non-null     int64
#  6   Home Run             30 non-null     int64
#  7   Base on Balls        30 non-null     int64
#  8   Strikeout            30 non-null     int64
#  9   Stolen Base          30 non-null     int64
#  10  Runs Average         30 non-null     int64
#  11  Earned Runs          30 non-null     int64
#  12  Earned Runs Average  30 non-null     float64
#  13  Complete Game        30 non-null     int64
#  14  Shot Out             30 non-null     int64
# ...

# %% [raw]
# # total no of columns=17
# # Total no of rows=30
# # All 16 columns are non-null and integer type Only Earned Runs Average is float type and it is also non-null
#   memory usage 4.1KB

# %%
# data Visualization

# %%
plt.figure(figsize=(10,5))
sns.histplot(x=df['RunScored'],kde=True)
plt.xticks(rotation=90)
plt.show()

# %%
sns.distplot(x=df['RunScored'])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['RunScored'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# Wins(W) and Runscored (R) are correlated.when RunScored is increase Wins is also increases.Data is shewed as per distribution plot

# %%
plt.figure(figsize=(10,5))
sns.distplot(x=df['At Bat'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['At Bat'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['At Bat'],y='wins',data=df)
# Out:
# <AxesSubplot:xlabel='At Bat', ylabel='wins'>

# %% [raw]
# #looks like At Bat is not related with wins

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Hits'])
# Out:
# <AxesSubplot:xlabel='Hits', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Hits'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# H(hits) is not related with W shewness found.

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Doubles'])
# Out:
# <AxesSubplot:xlabel='Doubles', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Doubles'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# Doubles is linearly related with wins.
# Distribution plot is slightly left skewed

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Triples'])
# Out:
# <AxesSubplot:xlabel='Triples', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Triples'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# 3B(Triple) is weakly related to W(Win)

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Home Run'])
# Out:
# <AxesSubplot:xlabel='Home Run', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Home Run'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# HR(Home Run) is weekly correlated with Wins and it is slightly right skewed

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Base on Balls'])
# Out:
# <AxesSubplot:xlabel='Base on Balls', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Base on Balls'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# # Base on Balls is slightly related with win

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Strikeout'])
# Out:
# <AxesSubplot:xlabel='Strikeout', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Strikeout'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Strikeout is very weekly related with target variable

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Stolen Base'])
# Out:
# <AxesSubplot:xlabel='Stolen Base', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Stolen Base'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Stolen Base is slightly related with W

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Runs Average'])
# Out:
# <AxesSubplot:xlabel='Runs Average', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Runs Average'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Runs Average has good correlation with Win

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Earned Runs'])
# Out:
# <AxesSubplot:xlabel='Earned Runs', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Earned Runs'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Earned Runs has good relation with win

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Earned Runs Average'])
# Out:
# <AxesSubplot:xlabel='Earned Runs Average', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Earned Runs Average'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Earned Runs Average has good relation with Win

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Complete Game'])
# Out:
# <AxesSubplot:xlabel='Complete Game', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Complete Game'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# Complete Game having no relation with target variable.skewness found in plot(distribution)

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Shot Out'])
# Out:
# <AxesSubplot:xlabel='Shot Out', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Shot Out'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
#Shot Out having linear relationship with Win

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Save'])
# Out:
# <AxesSubplot:xlabel='Save', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Save'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# SV(Save)is slightly related with target ,and data is slightly skewed

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Errors'])
# Out:
# <AxesSubplot:xlabel='Errors', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x=df['Errors'],y='wins',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# E(Errors)is not related with Wins.skewness observe

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in df:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        plt.scatter(df[column],df['wins'])
        plt.xlabel(column,fontsize=10)
        plt.ylabel('wins',fontsize=10)
    plotnumber+=1
plt.show()

# %% [raw]
# observation of visualization: 1.Earned Run,Earned Runs Average,Runs Average having good relation with target variable.
#                               2.Save,Earned Run,Earned Run Average,Runs Average,Runscored,Shotout having linear relation with
#                                 target.
#                               3. Other features having non-linear relationship.

# %% [raw]
# # Checking Correlation with Heatmap

# %%
corr=df.corr()
corr.shape
# Out:
# (17, 17)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
corr['wins'].sort_values()
# Out:
# Earned Runs Average   -0.819600
# Runs Average          -0.812952
# Earned Runs           -0.809435
# Triples               -0.251118
# Stolen Base           -0.157234
# Errors                -0.089485
# At Bat                -0.087947
# Hits                   0.037612
# Complete Game          0.080533
# Strikeout              0.111850
# Home Run               0.307407
# Doubles                0.427797
# RunScored              0.430751
# Shot Out               0.471805
# Base on Balls          0.484342
# Save                   0.666530
# wins                   1.000000
# Name: wins, dtype: float64

# %%
corr['Earned Runs Average'].sort_values(ascending=False)
# Out:
# Earned Runs Average    1.000000
# Earned Runs            0.997248
# Runs Average           0.986674
# Triples                0.330951
# At Bat                 0.255551
# Hits                   0.231172
# Stolen Base            0.126063
# Errors                 0.113137
# Complete Game         -0.009856
# RunScored             -0.049281
# Home Run              -0.090917
# Strikeout             -0.180368
# Doubles               -0.254854
# Base on Balls         -0.459832
# Save                  -0.607005
# Shot Out              -0.630833
# wins                  -0.819600
# Name: Earned Runs Average, dtype: float64

# %% [raw]
# # Observation:
# 1.Earned Run,Earned Runs Average,Runs Average are strong and negetively correlated with W(wins)i.e (-0.81 appr.).Save is
#   positively correlated with W(wins) i.e (0.66)
# 2.Save,Shot Out have positive correlation with Earned Run,Earned Runs Average,Runs Average(above 0.60)
# 3.Base on Balls is negatively correlated with Earned Run,Earned Runs Average,Runs Average i.e (0.42,0.45,0.46)
# 4.Earned Run,Earned Runs Average,Runs Average have strong corelation with each other (i.e 0.99) so  multi-correlation problem exist.we will drop Earned Runs,Earned Runs Average and check correlation

# %%
df=df.drop(columns=['Earned Runs','Earned Runs Average'],axis=1)

# %%
df.head()
# Out:
#    wins  RunScored  At Bat  Hits  Doubles  Triples  Home Run  Base on Balls  \
# 0    95        724    5575  1497      300       42       139            383
# 1    83        696    5467  1349      277       44       156            439
# 2    81        669    5439  1395      303       29       141            533
# 3    76        622    5533  1381      260       27       136            404
# 4    74        689    5605  1515      289       49       151            455
#
#    Strikeout  Stolen Base  Runs Average  Complete Game  Shot Out  Save  Errors
# 0        973          104           641              2         8    56      88
# 1       1264           70           700              2        12    45      86
# 2       1157           86           640             11        10    38      79
# 3       1231           68           701              7         9    37     101
# 4       1259           83           803              7        12    35      86

# %%
corr=df.corr()
corr.shape
# Out:
# (15, 15)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
corr['wins'].sort_values(ascending=False)
# Out:
# wins             1.000000
# Save             0.666530
# Base on Balls    0.484342
# Shot Out         0.471805
# RunScored        0.430751
# Doubles          0.427797
# Home Run         0.307407
# Strikeout        0.111850
# Complete Game    0.080533
# Hits             0.037612
# At Bat          -0.087947
# Errors          -0.089485
# Stolen Base     -0.157234
# Triples         -0.251118
# Runs Average    -0.812952
# Name: wins, dtype: float64

# %%
# Runs Average and Save are correlated with wins i.e -88% and +0.66% but we will consider it

# %%
# checking skewness

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in df:
    if plotnumber<=15:
        ax=plt.subplot(3,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
df.skew().sort_values(ascending=False)
# Out:
# RunScored        1.200786
# Errors           0.890132
# Complete Game    0.736845
# Hits             0.670254
# Save             0.657524
# Shot Out         0.565790
# Home Run         0.516441
# Stolen Base      0.479893
# At Bat           0.183437
# Base on Balls    0.158498
# Triples          0.129502
# wins             0.047089
# Runs Average     0.045734
# Strikeout       -0.156065
# Doubles         -0.230650
# dtype: float64

# %%
# Data is slightly skewed we will remove it
# For removing skewness will will power transform data and check skewness

# %%
x=df.drop(columns=['wins'],axis=1)
y=df['wins']

# %%
from sklearn.preprocessing import power_transform
df1=power_transform(x)

# %%
type(df1)
# Out:
# numpy.ndarray

# %%
df1=pd.DataFrame(df1,columns=x.columns)

# %%
df1
# Out:
#     RunScored  At Bat  Hits   Doubles   Triples  Home Run  Base on Balls  \
# 0         0.0     0.0   0.0  1.477685  1.033103 -0.764626      -1.610915
# 1         0.0     0.0   0.0  0.084269  1.203320 -0.158581      -0.502749
# 2         0.0     0.0   0.0  1.670782 -0.160270 -0.689676       1.128294
# 3         0.0     0.0   0.0 -0.848600 -0.360521 -0.879049      -1.181207
# 4         0.0     0.0   0.0  0.792183  1.616444 -0.329850      -0.206771
# 5         0.0     0.0   0.0  1.998506 -1.461062  1.937860       1.708067
# 6         0.0     0.0   0.0 -0.198558 -1.224911  1.460099       1.461121
# 7         0.0     0.0   0.0 -1.556454 -1.110302  1.583551      -0.904450
# 8         0.0     0.0   0.0  0.141687  0.130611  0.200058      -0.559191
# 9         0.0     0.0   0.0  1.099405  0.225256  0.007404       0.204599
# 10        0.0     0.0   0.0  0.199390  0.130611  0.355503       0.634349
# 11        0.0     0.0   0.0  0.141687 -0.462732  1.891937       0.344014
# ...

# %%
df1.skew().sort_values(ascending=False)
# Out:
# Errors           0.063909
# Strikeout        0.041170
# Shot Out         0.006560
# Save             0.000836
# RunScored        0.000000
# At Bat           0.000000
# Hits             0.000000
# Home Run        -0.000065
# Base on Balls   -0.007760
# Runs Average    -0.008082
# Stolen Base     -0.010455
# Doubles         -0.035315
# Complete Game   -0.059785
# Triples         -0.072933
# dtype: float64

# %%
# Skewness threshold is taken between +/-0.5 and there is no skewness

# %%
# Checking outlier

# %%
from scipy.stats import zscore

# %%
(np.abs(zscore(x))<3).all()
# Out:
# False

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
z_score=zscore(df[['Errors','Save','Shot Out','RunScored']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (29, 15)

# %%
x=df.drop(columns=['wins'],axis=1)
y=df['wins']

# %%
x.shape,y.shape
# Out:
# ((29, 14), (29,))

# %%
(np.abs(zscore(x))<3).all()
# Out:
# True

# %%
# percentage of data_loss

# %%
data_loss=(30-29)/30*100

# %%
data_loss
# Out:
# 3.3333333333333335

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled.shape[1]
# Out:
# 14

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range (x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#     vif       features
# 0   1.0      RunScored
# 1   1.0         At Bat
# 2   1.0           Hits
# 3   1.0        Doubles
# 4   1.0        Triples
# 5   1.0       Home Run
# 6   1.0  Base on Balls
# 7   1.0      Strikeout
# 8   1.0    Stolen Base
# 9   1.0   Runs Average
# 10  1.0  Complete Game
# 11  1.0       Shot Out
# 12  1.0           Save
# 13  1.0         Errors

# %%
# VIF values are <5 means no multicolinearity exist

# %%
pca=PCA()

# %%
pca.fit_transform(x_scaled)
# Out:
# array([[-2.95799580e+00, -9.53253423e-01,  2.24631635e+00,
#         -1.21699438e+00, -2.35731397e+00,  1.61248577e-02,
#          6.26783343e-01,  3.94845853e-01,  8.82534038e-01,
#          5.54003526e-01, -2.58275008e-01, -2.18896185e-01,
#         -1.76118892e-01,  1.92274757e-01],
#        [ 2.40394493e-01,  4.17410980e-01,  3.13525768e-01,
#         -2.66702903e-01, -2.94762949e-01,  5.04699369e-01,
#         -9.62595751e-01,  1.24039971e+00,  2.56175919e-01,
#         -8.27709942e-01,  3.32404411e-01, -1.99270043e-01,
#         -1.09779327e-02,  4.86047403e-01],
#        [ 4.74141013e-01, -1.10662084e+00,  9.11147099e-01,
#          3.09928139e+00, -7.96596416e-01, -7.62580927e-01,
#          1.54202142e+00,  1.35559677e+00, -2.35204461e-01,
#          1.59777072e-01,  5.49155058e-01,  8.20157996e-02,
#          2.05975668e-01, -1.16133360e-01],
#        [-1.09472748e-01,  1.84819808e+00,  1.63537671e-01,
#          1.09304628e+00,  3.00076570e-01, -1.01980494e+00,
# ...

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('principal components')
plt.ylabel('varience covered')
plt.title('pca')
plt.show()

# %%
pca=PCA(n_components=14)
new_pcomp=pca.fit_transform(x_scaled)

# %%
x=pd.DataFrame(new_pcomp,columns=x.columns)

# %%
x.head()
# Out:
#    RunScored    At Bat      Hits   Doubles   Triples  Home Run  Base on Balls  \
# 0  -2.957996 -0.953253  2.246316 -1.216994 -2.357314  0.016125       0.626783
# 1   0.240394  0.417411  0.313526 -0.266703 -0.294763  0.504699      -0.962596
# 2   0.474141 -1.106621  0.911147  3.099281 -0.796596 -0.762581       1.542021
# 3  -0.109473  1.848198  0.163538  1.093046  0.300077 -1.019805      -0.127039
# 4  -2.909976 -0.777732 -0.319362  1.853279 -0.148994  0.213535      -1.046595
#
#    Strikeout  Stolen Base  Runs Average  Complete Game  Shot Out      Save  \
# 0   0.394846     0.882534      0.554004      -0.258275 -0.218896 -0.176119
# 1   1.240400     0.256176     -0.827710       0.332404 -0.199270 -0.010978
# 2   1.355597    -0.235204      0.159777       0.549155  0.082016  0.205976
# 3   0.024300    -0.562258      1.324900      -0.151055 -0.102882  0.737932
# 4   0.188747    -1.268692     -0.264274      -0.364419  0.118457 -0.147223
#
#      Errors
# 0  0.192275
# 1  0.486047
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=47)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((21, 14), (21,), (8, 14), (8,))

# %%
# Best Features selection:

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
best_features=SelectKBest(score_func=f_classif,k='all')

# %%
fit=best_features.fit(x,y)

# %%
df_scores=pd.DataFrame(fit.scores_)

# %%
df_columns=pd.DataFrame(x.columns)

# %%
feature_scores=pd.concat([df_columns,df_scores],axis=1)

# %%
feature_scores.columns=['Feature_name','score']

# %%
print(feature_scores.nlargest(15,'score'))
# Out:
#      Feature_name     score
# 9    Runs Average  3.871902
# 4         Triples  3.115306
# 0       RunScored  1.713140
# 1          At Bat  1.686616
# 5        Home Run  1.351735
# 10  Complete Game  1.307508
# 2            Hits  1.235268
# 12           Save  1.190445
# 8     Stolen Base  1.136561
# 13         Errors  0.656525
# 7       Strikeout  0.502076
# 3         Doubles  0.469991
# 6   Base on Balls  0.463361
# 11       Shot Out  0.450885

# %%
# now BaseBall prediction model is ready for training

# %%
#finding best random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import statsmodels.formula.api as smf

# %%
lr=LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    lr_predict_train=lr.predict(x_train)
    y_pred_lr=lr.predict(x_test)
    print(f"At random state{i}, The training accuracy is : {r2_score(y_train,lr_predict_train)}")
    print(f"At random state{i}, The test accuracy is : {r2_score(y_test,y_pred_lr)}")
# Out:
# At random state0, The training accuracy is : 0.9790367754642569
# At random state0, The test accuracy is : 0.04630490791385511
# At random state1, The training accuracy is : 0.9539359149878681
# At random state1, The test accuracy is : 0.5973814079766829
# At random state2, The training accuracy is : 0.9469764104656936
# At random state2, The test accuracy is : -1.0455849664592964
# At random state3, The training accuracy is : 0.9630405103153918
# At random state3, The test accuracy is : 0.18900736047817712
# At random state4, The training accuracy is : 0.9558660749308142
# At random state4, The test accuracy is : 0.7681721431827753
# At random state5, The training accuracy is : 0.9530017380613709
# At random state5, The test accuracy is : 0.4782047759984668
# At random state6, The training accuracy is : 0.9557497720126272
# At random state6, The test accuracy is : 0.6610007477433353
# At random state7, The training accuracy is : 0.9233034812564622
# ...

# %% [raw]
# At random state47, The training accuracy is : 0.9117630088246775
# At random state47, The test accuracy is : 0.9183680014268838

# %%
import statsmodels.api as sm
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
svr=SVR()
dt=DecisionTreeRegressor()
rfc=RandomForestRegressor()

# %%
#linear Regression
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9183680014268838

# %%
y_pred_lr=lr.predict(x_test)

# %%
# comparing actual values with predicted values

actual_vs_pred = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_lr})
actual_vs_pred.sample(8)
# Out:
#     Actual  Predicted
# 28      74  72.253284
# 3       76  75.213210
# 6       87  86.646424
# 19      64  64.693633
# 0       95  88.823275
# 11      86  84.333795
# 15     100  94.745647
# 13      76  78.879026

# %%
plt.scatter(y_test,y_pred_lr)
plt.xlabel('actual Win')
plt.ylabel('predicted Win')
plt.show()

# %%
print('Mean absolute error :',(metrics.mean_absolute_error(y_test,y_pred_lr)))
print('Mean squared error :',(metrics.mean_squared_error(y_test,y_pred_lr)))
print('Root mean squared error :',(np.sqrt(mean_squared_error(y_test,y_pred_lr))))
print('R2 value is :',(r2_score(y_test,y_pred_lr)))
# Out:
# Mean absolute error : 2.4446281032216035
# Mean squared error : 10.137673822798861
# Root mean squared error : 3.1839713916426544
# R2 value is : 0.9183680014268838

# %%
#SVR
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
svr.score(x_test,y_test)
# Out:
# 0.030791826259959354

# %%
y_pred_svr=svr.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_pred_svr))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_svr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred_svr)))
# Out:
# MAE: 9.31638476014255
# MSE: 120.3635400763413
# RMSE: 10.971031860146123

# %%
#using Decisiontree regressor

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_test,y_test)
# Out:
# 0.1987921489682939

# %%
y_pred_dt=dt.predict(x_test)

# %%
y_predict_dt=dt.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_predict_dt))
print('MSE:', metrics.mean_squared_error(y_test, y_predict_dt))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_predict_dt)))
# Out:
# MAE: 8.25
# MSE: 99.5
# RMSE: 9.974968671630002

# %%
#using KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
# Out:
# 0.5501560140915952

# %%
y_predict_knn=knn.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_predict_knn))
print('MSE:', metrics.mean_squared_error(y_test, y_predict_knn))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_predict_knn)))
# Out:
# MAE: 6.325000000000001
# MSE: 55.86500000000002
# RMSE: 7.474289263869845

# %%
#using random forest regressor

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfc.score(x_test,y_test)
# Out:
# 0.4333999999999998

# %%
y_predict_rfc=rfc.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_predict_rfc))
print('MSE:', metrics.mean_squared_error(y_test, y_predict_rfc))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_predict_rfc)))
# Out:
# MAE: 6.296250000000001
# MSE: 70.36463750000003
# RMSE: 8.388363219365267

# %%
# Linear Regressor gives 92% accuracy
# Decision Tree gives 19% accuracy
# Random Forest gives 43% accuracy
# KNN gives 55% accuracy

# Here Linear Regressor gives better accuracy than other regressor

# %%
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(svr,x_scaled,y,cv=10)
# Out:
# array([-1.07299646e+00,  6.80021468e-03, -3.62494739e+00, -2.74161148e+01,
#        -2.06723887e-04, -2.47216083e-01,  2.92078867e-02, -1.96018478e+01,
#        -6.51054261e-01, -1.05553141e+01])

# %%
cross_val_score(svr,x_scaled,y,cv=10).mean()
# Out:
# -6.313368955969862

# %%
cross_val_score(dt,x_scaled,y,cv=5)
# Out:
# array([-2.6375    , -2.44736842,  0.5775826 ,  0.41639344, -0.74528302])

# %%
cross_val_score(dt,x_scaled,y,cv=5).mean()
# Out:
# -0.8043160850350883

# %%
cross_val_score(rfc,x_scaled,y,cv=5)
# Out:
# array([-0.27133455, -2.67415658,  0.03646675,  0.16893852,  0.41240625])

# %%
cross_val_score(rfc,x_scaled,y,cv=5).mean()
# Out:
# -0.5800840549795759

# %%
cross_val_score(knn,x_scaled,y,cv=5)
# Out:
# array([ 0.22804545, -1.73263158,  0.03099958, -0.20662295,  0.30035377])

# %%
cross_val_score(knn,x_scaled,y,cv=5).mean()
# Out:
# -0.2759711439743457

# %%
# Regularization

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10,100],'random_state':list(range(0,100))}

# %%
ls=Lasso()

# %%
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
clf.best_params_
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=.0001,random_state=0)

# %%
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.0001, random_state=0)

# %%
ls.score(x_train,y_train)
# Out:
# 0.9117629921082978

# %%
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)

# %%
lss
# Out:
# 0.9182448533138766

# %%
# In Linear regression after regularization we get 92% accuracy

# %%
# Hypertuning - GridSearchCV(using Random Forest Regressor)

# %%
parameters={"criterion":['mse','mae'],
            "max_features" :['auto','sqrt','log2'],
            "min_samples_split":[1,2,3,4]
             }

# %%
rfc=RandomForestRegressor()

# %%
grid_search=GridSearchCV(rfc,parameters)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [1, 2, 3, 4]})

# %%
best_parameters=grid_search.best_params_

# %%
best_parameters
# Out:
# {'criterion': 'mse', 'max_features': 'auto', 'min_samples_split': 2}

# %%
clf=RandomForestRegressor(criterion='mse' ,max_features='auto',min_samples_split=2)

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='mse')

# %%
y_pred=clf.predict(x_test)

# %%
plt.scatter(y_test,y_pred)

# %%
print(r2_score(y_test,y_pred)*100)
print(cross_val_score(rfc,x_scaled,y,cv=5).mean())
# Out:
# 38.557433316557656
# -0.31577806592340973

# %%
# # Hypertuning - GridSearchCV(using DecisionTree)

# %%
parameters={"criterion":['mse','mae'],
            "max_features" :['auto','sqrt','log2'],
             'min_samples_leaf':[10],
             'max_depth':[15]
            }

# %%
dt=DecisionTreeRegressor()

# %%
grid_search=GridSearchCV(dt,parameters)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [15],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [10]})

# %%
best_param=grid_search.best_params_

# %%
best_param
# Out:
# {'criterion': 'mse',
#  'max_depth': 15,
#  'max_features': 'auto',
#  'min_samples_leaf': 10}

# %%
clf=DecisionTreeRegressor(criterion='mse',max_features='auto',max_depth=15,min_samples_leaf =10)

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=15, max_features='auto',
#                       min_samples_leaf=10)

# %%
y_pred_dt=clf.predict(x_test)

# %%
y_pred_dt=clf.predict(x_test)

# %%
plt.scatter(y_test,y_pred)

# %%
print(r2_score(y_test,y_pred_dt)*100)
print(cross_val_score(dt,x_scaled,y,cv=5).mean())
# Out:
# 60.83548020812968
# -0.9751801596397576

# %%
# Decision Tree regressor gives r2 score 60% after tunning

# %%
# Saving model with best parameter(linear regression model)
import joblib
joblib.dump(lss,'BaseBall_regression.pkl')

# %% [raw]
# conclusion:
# # Here Linear Regression is the best model as we get    :-       R2 value is : 92%
#                                                                Mean absolute error : 2.4446281032216035
#                                                                Mean squared error : 10.137673822798861
#                                                                Root mean squared error : 3.1839713916426544
