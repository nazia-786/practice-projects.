# %% [raw]
# Red Wine Quality Prediction
#
# Problem Statement:
#
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.)
#
# This dataset can be viewed as classification task. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.
#
# Attribute Information
#
# Input variables (based on physicochemical tests):
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
# Output variable (based on sensory data):
# 12 - quality (score between 0 and 10)
#
# What might be an interesting thing to do, is to set an arbitrary cutoff for your dependent variable (wine quality) at e.g. 7 or higher getting classified as 'good/1' and the remainder as 'not good/0'.
# This allows you to practice with hyper parameter tuning on e.g. decision tree algorithms looking at the ROC curve and the AUC value.
#
# You need to build a classification model.
#
# Inspiration
#
# Use machine learning to determine which physiochemical properties make a wine 'good'!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\91964\Desktop\nazia\datascience\Projects_DT\winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.shape
# Out:
# (1599, 12)

# %%
# EDA (Analysis of data)

# %%
sns.scatterplot(x='fixed acidity',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(x='citric acid',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(x='residual sugar',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x='chlorides',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='density',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(x='pH',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(x='sulphates',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(x='alcohol',y='quality',data=data)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
# we can not conclude any single feature so we combine it and check correlation

# %%
data.corr()['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [raw]
# #we have make it as a classification problem we have to set an arbitrary cutoff for our dependent variable (wine quality) at e.g. 7 or higher getting classified as 'good/1' and the remainder as 'not good/0'.
# so we change our target as follows:

# %%
df=pd.DataFrame(data)

# %%
def testfunction(k):
    if k>=7:
        return 1
    else:
        return 0

# %%
df['Quality']=df['quality'].apply(testfunction)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Quality
# 0      9.4        5        0
# ...

# %%
df=df.drop(columns='quality',axis=1)

# %%
df['Quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: Quality, dtype: int64

# %% [raw]
# # it is a imbalanced dataset because there are many more normal wines than good or poor so we will keep it as it is.

# %%
# correlation with Heatmap

# %%
corr=df.corr()

# %%
plt.figure(figsize=(15,7))
sns.heatmap(corr,annot=True)
plt.show()

# %%
corr['fixed acidity'].sort_values(ascending=False)
# Out:
# fixed acidity           1.000000
# citric acid             0.671703
# density                 0.668047
# sulphates               0.183006
# Quality                 0.120061
# residual sugar          0.114777
# chlorides               0.093705
# alcohol                -0.061668
# total sulfur dioxide   -0.113181
# free sulfur dioxide    -0.153794
# volatile acidity       -0.256131
# pH                     -0.682978
# Name: fixed acidity, dtype: float64

# %%
corr['pH'].sort_values(ascending=False)
# Out:
# pH                      1.000000
# volatile acidity        0.234937
# alcohol                 0.205633
# free sulfur dioxide     0.070377
# Quality                -0.057283
# total sulfur dioxide   -0.066495
# residual sugar         -0.085652
# sulphates              -0.196648
# chlorides              -0.265026
# density                -0.341699
# citric acid            -0.541904
# fixed acidity          -0.682978
# Name: pH, dtype: float64

# %%
corr['total sulfur dioxide'].sort_values(ascending=False)
# Out:
# total sulfur dioxide    1.000000
# free sulfur dioxide     0.667666
# residual sugar          0.203028
# volatile acidity        0.076470
# density                 0.071269
# chlorides               0.047400
# sulphates               0.042947
# citric acid             0.035533
# pH                     -0.066495
# fixed acidity          -0.113181
# Quality                -0.139517
# alcohol                -0.205654
# Name: total sulfur dioxide, dtype: float64

# %%
corr['density'].sort_values(ascending=False)
# Out:
# density                 1.000000
# fixed acidity           0.668047
# citric acid             0.364947
# residual sugar          0.355283
# chlorides               0.200632
# sulphates               0.148506
# total sulfur dioxide    0.071269
# volatile acidity        0.022026
# free sulfur dioxide    -0.021946
# Quality                -0.150460
# pH                     -0.341699
# alcohol                -0.496180
# Name: density, dtype: float64

# %% [raw]
# # Outcome of correlation
#
#  1.Alcohol is 47% related with quality.
#  2.sulphates is 25% related with quality.
#  3.citric acid is 22% related with quality.
#  4.fixed acidity is 12% related with quality.
#  5.residual sugar is 1.3% related with quality.
#  6.free sulfur dioxide is 5% negatively related with quality.
#  7.pH is also 5% negatively related with quality.
#  8.chlorides is 12% negatively related with quality
#  9.density is 17% negatively related with quality
#  10.total sulfur dioxide is 18% negatively related with quality
#  11.volatile acidity is 39% negatively related with quality
#
#  fixed acidity is (+)vely correlated with citric acid(67%),density(66%) and (-)vely correlated with pH (68%).
#  total sulfur dioxide is 67% correlated with free sulfur dioxide
#
# There is strong correlation exist between some features

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [raw]
# # outcome of describe  of wine-red dataset
# There is no missing data
# total rows = 1599
# total columns = 12
# 1.fixed acidity: mean=8.3,std=1.74,min=4.6,max=15.9
# 2.volatile acidity: mean=0.527,std=0.179,min=0.12,max=1.58
# 3.citric acid   : mean=0.27,std=0.19,min=0,max=1
# 4.residual sugar: mean=2.53,std=1.40,min=0.9,max=15.5
# 5.chlorides : mean=0.087,std=0.047,min=0.012,max=0.611
# 6.free sulfur dioxide : mean=15.87,std=10.4,min=1.0,max=72
# 7.total sulfur dioxide : mean=46.46,std=32.89,min=6.0,max=289
# 8.density : mean=.99,std=.001,min=0.99,max=1.00
# 9.pH : mean=3.31,std=.15,min=2.74,max=4.0
# 10.sulphates :  mean=0.65,std=.169,min=.33,max=2.0
# 11.alcohol :  mean=10.4,std=1.06,min=8.4,max=14.9
# 12.quality : it is outcome of dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  Quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Total 1599 rows and 12 columns.All columns are float type data and quality is integer type data.Memory usage 150.0KB

# %%
#Checking skewness

# %%
df.skew().sort_values(ascending=False)
# Out:
# chlorides               5.680347
# residual sugar          4.540655
# sulphates               2.428672
# Quality                 2.129363
# total sulfur dioxide    1.515531
# free sulfur dioxide     1.250567
# fixed acidity           0.982751
# alcohol                 0.860829
# volatile acidity        0.671593
# citric acid             0.318337
# pH                      0.193683
# density                 0.071288
# dtype: float64

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in df:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#skewness is present we will remove skewness by power transform

# %%
from sklearn.preprocessing import power_transform

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
df1=power_transform(x)

# %%
type(df1)
# Out:
# numpy.ndarray

# %%
df1=pd.DataFrame(df1,columns=x.columns)

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.442666          0.995542    -1.531109       -0.597145  -0.172896
# 1         -0.161308          1.771299    -1.531109        0.556565   0.786204
# 2         -0.161308          1.269801    -1.255359        0.152372   0.560696
# 3          1.522582         -1.550050     1.398471       -0.597145  -0.226113
# 4         -0.442666          0.995542    -1.531109       -0.597145  -0.172896
# ...             ...               ...          ...             ...        ...
# 1594      -1.461202          0.497996    -0.993315       -0.380998   0.480036
# 1595      -1.767458          0.227895    -0.867068       -0.008632  -1.013159
# 1596      -1.364367          0.000387    -0.683294        0.152372  -0.172896
# 1597      -1.767458          0.728553    -0.743826       -0.380998  -0.226113
# 1598      -1.662640         -1.320459     1.031070        1.375435  -0.688299
#
# ...

# %%
df1.skew().sort_values(ascending=False)
# Out:
# alcohol                 0.112372
# citric acid             0.017788
# sulphates               0.009985
# volatile acidity        0.003099
# fixed acidity           0.002529
# pH                     -0.002823
# total sulfur dioxide   -0.003752
# density                -0.005054
# free sulfur dioxide    -0.009948
# residual sugar         -0.015715
# chlorides              -0.151304
# dtype: float64

# %%
#skewness value is accepted +/-0.5.No skewness is exist

# %%
#checking outliers

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
x.shape,y.shape
# Out:
# ((1599, 11), (1599,))

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore

# %%
np.abs(zscore(df)<3).all()
# Out:
# False

# %%
x.shape,y.shape
# Out:
# ((1599, 11), (1599,))

# %%
z_score=zscore(df[['sulphates','alcohol','pH','chlorides','density','fixed acidity','volatile acidity','citric acid','residual sugar','free sulfur dioxide','total sulfur dioxide']])

# %%
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1458, 12)

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
x.shape,y.shape
# Out:
# ((1458, 11), (1458,))

# %%
np.abs(zscore(df)<3).all()
# Out:
# False

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
z_score=zscore(df[['sulphates','alcohol','pH','chlorides','density','fixed acidity','volatile acidity','citric acid','residual sugar','free sulfur dioxide','total sulfur dioxide']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1327, 12)

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
x.shape,y.shape
# Out:
# ((1327, 11), (1327,))

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
np.abs(zscore(df)<3).all()
# Out:
# False

# %%
z_score=zscore(df[['sulphates','alcohol','pH','chlorides','density','fixed acidity','volatile acidity','citric acid','residual sugar','free sulfur dioxide','total sulfur dioxide']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1269, 12)

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
x.shape,y.shape
# Out:
# ((1269, 11), (1269,))

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
np.abs(zscore(df)<3).all()
# Out:
# False

# %%
z_score=zscore(df[['sulphates','alcohol','pH','chlorides','density','fixed acidity','volatile acidity','citric acid','residual sugar','free sulfur dioxide','total sulfur dioxide']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1239, 12)

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
x.shape,y.shape
# Out:
# ((1239, 11), (1239,))

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
np.abs(zscore(df)<3).all()
# Out:
# False

# %%
z_score=zscore(df[['sulphates','alcohol','pH','chlorides','density','fixed acidity','volatile acidity','citric acid','residual sugar','free sulfur dioxide','total sulfur dioxide']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1221, 12)

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
x.shape,y.shape
# Out:
# ((1221, 11), (1221,))

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
np.abs(zscore(df)<3).all()
# Out:
# False

# %%
z_score=zscore(df[['sulphates','alcohol','pH','chlorides','density','fixed acidity','volatile acidity','citric acid','residual sugar','free sulfur dioxide','total sulfur dioxide']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1220, 12)

# %%
x=df.drop('Quality',axis=1)
y=df['Quality']

# %%
x.shape,y.shape
# Out:
# ((1220, 11), (1220,))

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
np.abs(zscore(df)<3).all()
# Out:
# True

# %%
x.shape,y.shape
# Out:
# ((1220, 11), (1220,))

# %%
# outliers are removed and all the points are falls in between +/-3

# %%
# now wine-red model is ready for training

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
scaler=StandardScaler()

# %%
x_scaler=scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,random_state=42,test_size=0.25)

# %%
# LOGISTIC REGRESSION

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred_lr)*100)
print(confusion_matrix(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# 85.90163934426229
# [[252  10]
#  [ 33  10]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       262
#            1       0.50      0.23      0.32        43
#
#     accuracy                           0.86       305
#    macro avg       0.69      0.60      0.62       305
# weighted avg       0.83      0.86      0.84       305

# %%
# DECISION TREE CLASSIFIER

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt=dt.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred_dt)*100)
print(confusion_matrix(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# 88.19672131147541
# [[244  18]
#  [ 18  25]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       262
#            1       0.58      0.58      0.58        43
#
#     accuracy                           0.88       305
#    macro avg       0.76      0.76      0.76       305
# weighted avg       0.88      0.88      0.88       305

# %%
# RANDOM TREE CLASSIFIER

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rfc=rfc.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred_rfc)*100)
print(confusion_matrix(y_test,y_pred_rfc))
print(classification_report(y_test,y_pred_rfc))
# Out:
# 91.14754098360656
# [[257   5]
#  [ 22  21]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       262
#            1       0.81      0.49      0.61        43
#
#     accuracy                           0.91       305
#    macro avg       0.86      0.73      0.78       305
# weighted avg       0.91      0.91      0.90       305

# %%
# KNN CLASSIFIER

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=knn.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred_knn)*100)
print(confusion_matrix(y_test,y_pred_knn))
print(classification_report(y_test,y_pred_knn))
# Out:
# 87.54098360655738
# [[254   8]
#  [ 30  13]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       262
#            1       0.62      0.30      0.41        43
#
#     accuracy                           0.88       305
#    macro avg       0.76      0.64      0.67       305
# weighted avg       0.86      0.88      0.86       305

# %%
#XGBOOST

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier(objective='binary:logistic')

# %%
xgb.fit(x_train,y_train)
# Out:
# [00:24:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_xgb=xgb.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred_xgb)*100)
print(confusion_matrix(y_test,y_pred_xgb))
print(classification_report(y_test,y_pred_xgb))
# Out:
# 90.81967213114754
# [[255   7]
#  [ 21  22]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       262
#            1       0.76      0.51      0.61        43
#
#     accuracy                           0.91       305
#    macro avg       0.84      0.74      0.78       305
# weighted avg       0.90      0.91      0.90       305

# %% [raw]
# By comparing the five models, the random forest and XGBoost seems give highest level of accuracy.
# XGBoost and random forest both has good f1-score for predicting good quality wines(1)

# %%
# now check for cross validation score as well as overfitting if exist

# %%
from sklearn.model_selection import cross_val_score

# %%
cvs_lr=cross_val_score(lr,x,y,cv=5)

# %%
print(cvs_lr.mean())
# Out:
# 0.8852459016393442

# %%
cvs_dt=cross_val_score(dt,x,y,cv=5)

# %%
print(cvs_dt.mean())
# Out:
# 0.8098360655737704

# %%
cvs_knn=cross_val_score(knn,x,y,cv=5)

# %%
print(cvs_knn.mean())
# Out:
# 0.8631147540983605

# %%
cvs_rfc=cross_val_score(rfc,x,y,cv=5)

# %%
print(cvs_rfc.mean())
# Out:
# 0.8942622950819672

# %%
cvs_xgb=cross_val_score(xgb,x,y,cv=5)
# Out:
# [00:25:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:25:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:25:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
print(cvs_xgb.mean())
# Out:
# 0.880327868852459

# %%
# Logistic Regression,Random Forest and XGBoost gives good accuracy

# %%
# Best feature selection method

# %%
from sklearn.feature_selection import SelectPercentile,chi2

# %%
spercentile=SelectPercentile(score_func=chi2,percentile=80)

# %%
spercentile.fit(x,y)
# Out:
# SelectPercentile(percentile=80,
#                  score_func=<function chi2 at 0x000001A3C2E280D0>)

# %%
cols=spercentile.get_support(indices=True)

# %%
features=x.columns[cols]

# %%
df_scores=pd.DataFrame({'features': x.columns,
                        'chi2score': spercentile.scores_,
                        'pvalue': spercentile.pvalues_})

# %%
df_scores.sort_values(by='chi2score',ascending=False)
# Out:
#                 features   chi2score         pvalue
# 6   total sulfur dioxide  484.639172  2.090644e-107
# 5    free sulfur dioxide   27.491605   1.577779e-07
# 10               alcohol   18.055991   2.145026e-05
# 2            citric acid    6.637609   9.984788e-03
# 1       volatile acidity    4.135162   4.200104e-02
# 0          fixed acidity    3.696830   5.451595e-02
# 9              sulphates    2.479940   1.153067e-01
# 4              chlorides    0.068533   7.934853e-01
# 8                     pH    0.032352   8.572565e-01
# 3         residual sugar    0.000778   9.777432e-01
# 7                density    0.000119   9.913032e-01

# %%
feat_importances = pd.Series(rfc.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("Top 10 important features in data")
plt.show()

# %%
feat_importances = pd.Series(xgb.feature_importances_, index=x.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("Top 10 important features in data")
plt.show()

# %%
## hypertuning the model with GridSearchCV (using xgb and random forest and decision tree parameters)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'learning_rate':[1,0.5,0.1,0.01],
            'max_depth':[3,5,7,9,11],
            'n_estimators':[10,20,30,40,100,200]
           }

# %%
grid=GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid)

# %%
grid.fit(x_train,y_train)
# Out:
# [00:26:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:26:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [00:26:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
grid.best_params_
# Out:
# {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 10}

# %%
clf=XGBClassifier(learning_rate= 0.1,max_depth=9,n_estimators=100)

# %%
clf.fit(x_train,y_train)
# Out:
# [00:26:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=9, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred=clf.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred)*100)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 89.8360655737705
# [[252  10]
#  [ 21  22]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       262
#            1       0.69      0.51      0.59        43
#
#     accuracy                           0.90       305
#    macro avg       0.81      0.74      0.76       305
# weighted avg       0.89      0.90      0.89       305

# %%
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(grid.best_estimator_,x_test,y_test)
plt.title('ROC_AUC plot')
plt.show()

# %%
#by using random forest

# %%
parameters={'max_features':['auto','sqrt','log2'],
            'max_depth':[4,5,6,7,8],
            'criterion':['gini','entropy']
           }

# %%
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')

# %%
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2']},
#              scoring='accuracy')

# %%
gcv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt'}

# %%
gcv_pred=gcv.best_estimator_.predict(x_test)

# %%
print(accuracy_score(y_test,gcv_pred)*100)
print(confusion_matrix(y_test,gcv_pred))
print(classification_report(y_test,gcv_pred))
# Out:
# 90.1639344262295
# [[258   4]
#  [ 26  17]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.95       262
#            1       0.81      0.40      0.53        43
#
#     accuracy                           0.90       305
#    macro avg       0.86      0.69      0.74       305
# weighted avg       0.89      0.90      0.89       305

# %%
plot_roc_curve(gcv.best_estimator_,x_test,y_test)
plt.title('ROC_AUC plot')
plt.show()

# %%
grid_param={'min_samples_leaf':[2,3,4,5],
            'max_depth':[4,5,6,7,8],
            'criterion':['gini','entropy'],
             'min_samples_split':[3,5,7,9],
             'max_leaf_nodes':[2,3,4]
           }

# %%
gcv_dt=GridSearchCV(estimator=DecisionTreeClassifier(),param_grid=grid_param,cv=5,n_jobs=-1)

# %%
gcv_dt.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_leaf_nodes': [2, 3, 4],
#                          'min_samples_leaf': [2, 3, 4, 5],
#                          'min_samples_split': [3, 5, 7, 9]})

# %%
best_parameters=gcv_dt.best_params_

# %%
best_parameters
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_leaf_nodes': 4,
#  'min_samples_leaf': 2,
#  'min_samples_split': 3}

# %%
gcv_pred_dt=gcv_dt.best_estimator_.predict(x_test)

# %%
print(accuracy_score(y_test,gcv_pred_dt)*100)
print(confusion_matrix(y_test,gcv_pred_dt))
print(classification_report(y_test,gcv_pred_dt))
# Out:
# 86.88524590163934
# [[253   9]
#  [ 31  12]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       262
#            1       0.57      0.28      0.37        43
#
#     accuracy                           0.87       305
#    macro avg       0.73      0.62      0.65       305
# weighted avg       0.85      0.87      0.85       305

# %%
plot_roc_curve(gcv_dt.best_estimator_,x_test,y_test)
plt.title('ROC_AUC plot')
plt.show()

# %%
# Final accuracy we can get by Random forest is 90% and AUC score 89% which is good

# %%
# Saving model
import joblib
joblib.dump(grid.best_estimator_,'wine-red1.pkl')
# Out:
# ['wine-red1.pkl']

# %% [raw]
# Conclusion:
#
# By comparing the five models, the random forest and xgboost seems give highest level of accuracy.
# XGBoost and Random forest both has good f1-score for predicting good quality wines(1).
# AUC value and cross validation score is good 89% for Random forest
# so here Random Forest is the best of the five models.
