# %% [raw]
# Customer Churn Analysis
# Problem Statement:
# Customer churn is when a company’s customers stop doing business with that company. Businesses are very keen on measuring churn because keeping an existing customer is far less expensive than acquiring a new customer. New business involves working leads through a sales funnel, using marketing and sales budgets to gain additional customers. Existing customers will often have a higher volume of service consumption and can generate additional customer referrals.
#
# Customer retention can be achieved with good customer service and products. But the most effective way for a company to prevent attrition of customers is to truly know them. The vast volumes of data collected about customers can be used to build churn prediction models. Knowing who is most likely to defect means that a company can prioritise focused marketing efforts on that subset of their customer base.
#
# Preventing customer churn is critically important to the telecommunications sector, as the barriers to entry for switching services are so low.
#
# You will examine customer data from IBM Sample Data Sets with the aim of building and comparing several customer churn prediction models.
#
# Note: You can find the dataset in the link below.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\91964\Desktop\nazia\datascience\Projects_DT\Telecom_customer_churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# EDA Analysis

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
#there is no missing value is present in the dataset

# %%
df.shape
# Out:
# (7043, 21)

# %%
# there are total 7043 rows and 21 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# There is no missing value is present in the dataset
# All are object types but SeniorCitizen is int64,tenure is int64,MonthlyCharges is float64 type
# There are float64type column is =(1), int64 type=(2), object type=(18)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# customerID is not important so we drop the column

# %%
df=df.drop(columns='customerID',axis=1)

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
df['tenure'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
df['PhoneService'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
df['MultipleLines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
# here No and No phone service is same so we will replace it

# %%
df['MultipleLines']=df.MultipleLines.replace('No phone service','No')

# %%
df['MultipleLines'].value_counts()
# Out:
# No     4072
# Yes    2971
# Name: MultipleLines, dtype: int64

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
df['OnlineSecurity'].value_counts()
# Out:
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64

# %%
# here No and No internet service is same so we will replace it

# %%
df['OnlineSecurity']=df['OnlineSecurity'].replace('No internet service','No')

# %%
df['OnlineSecurity'].value_counts()
# Out:
# No     5024
# Yes    2019
# Name: OnlineSecurity, dtype: int64

# %%
df['OnlineBackup'].value_counts()
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
# here No and No internet service is same so we will replace it

# %%
df['OnlineBackup']=df['OnlineBackup'].replace('No internet service','No')

# %%
df['OnlineBackup'].value_counts()
# Out:
# No     4614
# Yes    2429
# Name: OnlineBackup, dtype: int64

# %%
df['DeviceProtection'].value_counts()
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
# here No and No internet service is same so we will replace it

# %%
df['DeviceProtection']=df['DeviceProtection'].replace('No internet service','No')

# %%
df['DeviceProtection'].value_counts()
# Out:
# No     4621
# Yes    2422
# Name: DeviceProtection, dtype: int64

# %%
df['TechSupport'].value_counts()
# Out:
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: TechSupport, dtype: int64

# %%
# here No and No internet service is same so we will replace it

# %%
df['TechSupport']=df['TechSupport'].replace('No internet service','No')

# %%
df['TechSupport'].value_counts()
# Out:
# No     4999
# Yes    2044
# Name: TechSupport, dtype: int64

# %%
df['StreamingMovies'].value_counts()
# Out:
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: StreamingMovies, dtype: int64

# %%
# here No and No internet service is same so we will replace it

# %%
df['StreamingMovies']=df['StreamingMovies'].replace('No internet service','No')

# %%
df['StreamingMovies'].value_counts()
# Out:
# No     4311
# Yes    2732
# Name: StreamingMovies, dtype: int64

# %%
df['StreamingTV'].value_counts()
# Out:
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: StreamingTV, dtype: int64

# %%
# here No and No internet service is same so we will replace it

# %%
df['StreamingTV']=df['StreamingTV'].replace('No internet service','No')

# %%
df['StreamingTV'].value_counts()
# Out:
# No     4336
# Yes    2707
# Name: StreamingTV, dtype: int64

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
df['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
df['MonthlyCharges'].value_counts()
# Out:
# 20.05     61
# 19.85     45
# 19.90     44
# 19.95     44
# 19.65     43
#           ..
# 87.65      1
# 35.30      1
# 114.85     1
# 56.50      1
# 97.25      1
# Name: MonthlyCharges, Length: 1585, dtype: int64

# %%
df['TotalCharges'].value_counts()
# Out:
# 20.2       11
#            11
# 19.75       9
# 19.9        8
# 20.05       8
#            ..
# 31.55       1
# 2909.95     1
# 1336.8      1
# 3233.6      1
# 3389.25     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %%
# Total charges are continuous data but its showing object type which is not possible
# so we will convert this,also it having null values

# %%
df['TotalCharges']=df['TotalCharges'].str.strip()

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'])

# %%
df['TotalCharges'].dtypes
# Out:
# dtype('float64')

# %%
df['TotalCharges'].value_counts()
# Out:
# 20.20      11
# 19.75       9
# 20.05       8
# 19.65       8
# 19.90       8
#            ..
# 6424.70     1
# 1474.35     1
# 6668.35     1
# 6096.90     1
# 5867.00     1
# Name: TotalCharges, Length: 6530, dtype: int64

# %%
df.isna().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges']=df['TotalCharges'].fillna(df['TotalCharges'].mean())

# %%
df.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2265.000258
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1400.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
# There is no missing value present
# all are continuous data
# MonthlyCharges: mean=64, std=30, min=18, max=118.75
# TotalCharges : mean=2283, std=2265, min=18.8, max=8685

# %%
df.describe(include='O')
# Out:
#        gender Partner Dependents PhoneService MultipleLines InternetService  \
# count    7043    7043       7043         7043          7043            7043
# unique      2       2          2            2             2               3
# top      Male      No         No          Yes            No     Fiber optic
# freq     3555    3641       4933         6361          4072            3096
#
#        OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# count            7043         7043             7043        7043        7043
# unique              2            2                2           2           2
# top                No           No               No          No          No
# freq             5024         4614             4621        4999        4336
#
#        StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# count             7043            7043             7043              7043
# ...

# %%
# There is no missing value present
# gender,Partner,Dependents,PhoneService,MultipleLines,InternetService,OnlineSecurity,OnlineBackup,
# DeviceProtection,TechSupport,StreamingTV,StreamingMovies,Contract,PaperlessBilling,PaymentMethod all are categorical data
# Churn is categorical data and it is target variable

# %%
plt.figure(figsize=(3,3))
sns.histplot(x=df['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %%
# male are slightly more than female

# %%
plt.figure(figsize=(3,3))
sns.histplot(x=df['Partner'])
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='Count'>

# %%
# single customers are more

# %%
plt.figure(figsize=(3,3))
sns.histplot(x=df['Dependents'])
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='Count'>

# %%
# Dependent customers are less than independents

# %%
plt.figure(figsize=(3,3))
sns.histplot(x=df['PhoneService'])
# Out:
# <AxesSubplot:xlabel='PhoneService', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='gender',hue='Churn',data=df)
plt.show()

# %%
# Both Female and male customer churn is same

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Partner',hue='Churn',data=df)
plt.show()

# %%
# churn chances are more for those who are single or dont have partner

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Dependents',hue='Churn',data=df)
plt.show()

# %%
# Churn chances are high for independent customer

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='PhoneService',hue='Churn',data=df)
plt.show()

# %%
# churn chances are high for those, having phoneservice

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='MultipleLines',hue='Churn',data=df)
plt.show()

# %%
# Chur chances are more for those not having multiplelines

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='InternetService',hue='Churn',data=df)
plt.show()

# %%
# Customers having Fiber optics internet service churn chances are high for them

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='OnlineSecurity',hue='Churn',data=df)
plt.show()

# %%
# customers who are not getting onlinesecurity churn chances are more

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='OnlineBackup',hue='Churn',data=df)
plt.show()

# %%
# customers who are not getting onlineBackup churn chances are more

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='DeviceProtection',hue='Churn',data=df)
plt.show()

# %%
# customers who are not getting Deviceprotection churn chances are more

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='TechSupport',hue='Churn',data=df)
plt.show()

# %%
# customers who are not getting Techsupport churn chances are more

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='StreamingTV',hue='Churn',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='StreamingMovies',hue='Churn',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Contract',hue='Churn',data=df)
plt.show()

# %%
# customers whose contract is on month-to-month basis they are more churn

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='PaperlessBilling',hue='Churn',data=df)
plt.show()

# %%
# customers who are interested in paperless billing churn more

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='PaymentMethod',hue='Churn',data=df)
plt.show()

# %%
# churn chances are more for electronic check paymentmode

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='SeniorCitizen',hue='Churn',data=df)
plt.show()

# %%
# seniorcitizen are not churn

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='tenure',hue='Churn',data=df)
plt.show()

# %%
# customer with more tenure less chances of churn

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x='MonthlyCharges',hue='Churn',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='MonthlyCharges',hue='Churn',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='MonthlyCharges',y='Churn',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x='TotalCharges',y='Churn',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='TotalCharges',hue='Churn',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.violinplot(x='TotalCharges',hue='Churn',data=df)
plt.show()

# %%
corr=df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)
plt.show()

# %%
df.skew().sort_values(ascending=False)
# Out:
# SeniorCitizen     1.833633
# TotalCharges      0.962394
# tenure            0.239540
# MonthlyCharges   -0.220524
# dtype: float64

# %%
# TotalCharges and SeniorCitizen has skewed data though SeniorCitizen is categorical no need to remove skewness

# %%
df['TotalCharges']=np.cbrt(df['TotalCharges'])

# %%
df.skew().sort_values(ascending=False)
# Out:
# SeniorCitizen     1.833633
# tenure            0.239540
# TotalCharges      0.011168
# MonthlyCharges   -0.220524
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
var=['gender','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod','Churn']
for i in var:
    
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              0                0               0             1
# 1              0                0               1             0
# 2              0                0               1             1
# 3              0                0               1             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
corr=df.corr()
plt.figure(figsize=(18,8))
sns.heatmap(corr,annot=True)
plt.show()

# %%
corr['Churn'].sort_values(ascending=False)
# Out:
# Churn               1.000000
# MonthlyCharges      0.193356
# PaperlessBilling    0.191825
# SeniorCitizen       0.150889
# PaymentMethod       0.107062
# StreamingTV         0.063228
# StreamingMovies     0.061382
# MultipleLines       0.040102
# PhoneService        0.011942
# gender             -0.008612
# InternetService    -0.047291
# DeviceProtection   -0.066160
# OnlineBackup       -0.082255
# Partner            -0.150448
# Dependents         -0.164221
# TechSupport        -0.164674
# OnlineSecurity     -0.171226
# TotalCharges       -0.233781
# tenure             -0.352229
# Contract           -0.396713
# Name: Churn, dtype: float64

# %%
## observation: 
# churn is negetively related with tenure,total_charges,contract,onlinesecurity and techsupport,dependents,partner
# internet service ,payment method is correlated with online backup,onlinesecurity,device protection,techsupport,
   # streammingTV,streammingmovies
# seniorcitizen related with dependents
# internetservice is related with total and monthlycharges

# %%
df.skew().sort_values(ascending=False)
# Out:
# SeniorCitizen       1.833633
# Churn               1.063031
# OnlineSecurity      0.943722
# TechSupport         0.924630
# Dependents          0.875199
# DeviceProtection    0.657450
# OnlineBackup        0.652817
# Contract            0.630959
# StreamingTV         0.475581
# StreamingMovies     0.460199
# MultipleLines       0.316610
# tenure              0.239540
# InternetService     0.205423
# Partner             0.067922
# TotalCharges        0.011168
# gender             -0.019031
# PaymentMethod      -0.170129
# MonthlyCharges     -0.220524
# PaperlessBilling   -0.375396
# PhoneService       -2.727153
# dtype: float64

# %%
# senior citizen,paperlessbilling,online security,techsupport,dependent,deviceprotection ,onlinebackup,contract
# and phoneService are skewed

# %%
plt.figure(figsize=(30,20))
plotnumber=1

for column in df:
    if plotnumber<=25:
        ax=plt.subplot(5,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=13)
    plotnumber+=1
plt.show()

# %%
x=df.drop(columns='Churn',axis=1)
y=df['Churn']

# %%
#checking outliers

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#identifying best features:

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
rf.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
plt.figure(figsize=(20,9))
feature_important=pd.Series(rf.feature_importances_, index=x.columns)
feature_important.nlargest(15).plot(kind='barh')
plt.show()

# %%
x.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges'],
#       dtype='object')

# %%
x=x.drop(columns=['PhoneService','MultipleLines','StreamingTV','StreamingMovies'],axis=1)

# %%
x.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  InternetService  \
# 0       0              0        1           0       1                0
# 1       1              0        0           0      34                0
# 2       1              0        0           0       2                0
# 3       1              0        0           0      45                0
# 4       0              0        0           0       2                1
#
#    OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  Contract  \
# 0               0             1                 0            0         0
# 1               1             0                 1            0         1
# 2               1             1                 0            0         0
# 3               1             0                 1            1         1
# 4               0             0                 0            0         0
#
#    PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# ...

# %%
x.skew().sort_values(ascending=False)
# Out:
# SeniorCitizen       1.833633
# OnlineSecurity      0.943722
# TechSupport         0.924630
# Dependents          0.875199
# DeviceProtection    0.657450
# OnlineBackup        0.652817
# Contract            0.630959
# tenure              0.239540
# InternetService     0.205423
# Partner             0.067922
# TotalCharges        0.011168
# gender             -0.019031
# PaymentMethod      -0.170129
# MonthlyCharges     -0.220524
# PaperlessBilling   -0.375396
# dtype: float64

# %%
plt.figure(figsize=(30,20))
plotnumber=1

for column in x:
    if plotnumber<=25:
        ax=plt.subplot(5,5,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column,fontsize=13)
    plotnumber+=1
plt.show()

# %%
# threshold of skewness is taken(+/-)1

# %%
# outliers

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=20:
        ax=plt.subplot(5,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore

# %%
(np.abs(zscore(x))<3).all()
# Out:
# True

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range (x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#           vif          features
# 0    1.001630            gender
# 1    1.139913     SeniorCitizen
# 2    1.462349           Partner
# 3    1.381872        Dependents
# 4   12.317294            tenure
# 5    1.569190   InternetService
# 6    1.434186    OnlineSecurity
# 7    1.441416      OnlineBackup
# 8    1.533685  DeviceProtection
# 9    1.514764       TechSupport
# 10   2.411913          Contract
# 11   1.195338  PaperlessBilling
# 12   1.178933     PaymentMethod
# 13   4.541880    MonthlyCharges
# 14  16.503561      TotalCharges

# %%
# vif value is more than 5 for totalcharges and tenure both are important so we keep the columns

# %%
from imblearn.over_sampling import SMOTE

# %%
#oversampling// upsampling

# %%
# Over Sampling for minority or Under Sampling for majority class
# Here we will do over-sampling as no of observation is less.
# Here we use SMOTE(Synthetic Minority Oversampling Technique)

# %%
sm=SMOTE()
x_,y_=sm.fit_resample(x,y)

# %%
y_.value_counts()
# Out:
# 0    5174
# 1    5174
# Name: Churn, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_,y_,test_size = 0.25,random_state=441)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((7761, 15), (7761,), (2587, 15), (2587,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# though we have done oversampling,there is a chance of getting high value of
#        accuracy so we consider confusion matrix,precion ,recall and f1score

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)
acc_lr=accuracy_score(y_test,y_pred_lr)*100
acc_lr
# Out:
# 79.70622342481639

# %%
print(confusion_matrix(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# [[1037  295]
#  [ 230 1025]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80      1332
#            1       0.78      0.82      0.80      1255
#
#     accuracy                           0.80      2587
#    macro avg       0.80      0.80      0.80      2587
# weighted avg       0.80      0.80      0.80      2587

# %%
# we get accuracy 79% with logistic regressor

# %%
# SUPPORT VECTOR CLASSIFIER
from sklearn.svm import SVC 
svc=SVC()
svc.fit(x_train,y_train)
y_pred_svc=svc.predict(x_test)
acc_svc=accuracy_score(y_test,y_pred_svc)*100
acc_svc
# Out:
# 75.45419404715888

# %%
print(confusion_matrix(y_test,y_pred_svc))
print(classification_report(y_test,y_pred_svc))
# Out:
# [[ 922  410]
#  [ 225 1030]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74      1332
#            1       0.72      0.82      0.76      1255
#
#     accuracy                           0.75      2587
#    macro avg       0.76      0.76      0.75      2587
# weighted avg       0.76      0.75      0.75      2587

# %%
# we get accuracy 81.3% with SVC

# %%
# DECISIONTREE CLASSIFIER

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred_dt=dt.predict(x_test)
acc_dt=accuracy_score(y_test,y_pred_dt)*100
acc_dt
# Out:
# 79.39698492462311

# %%
print(confusion_matrix(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# [[1032  300]
#  [ 233 1022]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79      1332
#            1       0.77      0.81      0.79      1255
#
#     accuracy                           0.79      2587
#    macro avg       0.79      0.79      0.79      2587
# weighted avg       0.80      0.79      0.79      2587

# %%
# we get accuracy 77% with DecisionTree Classifier

# %%
# RANDOM FOREST CLASSIFIER

rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred_rfc=rfc.predict(x_test)
acc_rfc=accuracy_score(y_test,y_pred_rfc)*100
acc_rfc
# Out:
# 84.19018167761885

# %%
print(confusion_matrix(y_test,y_pred_rfc))
print(classification_report(y_test,y_pred_rfc))
# Out:
# [[1091  241]
#  [ 168 1087]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      1332
#            1       0.82      0.87      0.84      1255
#
#     accuracy                           0.84      2587
#    macro avg       0.84      0.84      0.84      2587
# weighted avg       0.84      0.84      0.84      2587

# %%
# we get accuracy 85% with RandomForest Classifier

# %%
#XG Boost
from xgboost import XGBClassifier
xgb=XGBClassifier(objective='binary:logistic')
xgb.fit(x_train,y_train)
y_pred_xgb=xgb.predict(x_test)
acc_xgb=accuracy_score(y_test,y_pred_xgb)*100
acc_xgb
# Out:
# [10:50:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 83.494395052184

# %%
print(confusion_matrix(y_test,y_pred_xgb))
print(classification_report(y_test,y_pred_xgb))
# Out:
# [[1072  260]
#  [ 167 1088]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83      1332
#            1       0.81      0.87      0.84      1255
#
#     accuracy                           0.83      2587
#    macro avg       0.84      0.84      0.83      2587
# weighted avg       0.84      0.83      0.83      2587

# %%
# we get accuaracy 80% with XGB Classifier

# %%
# Model Evaluation

Models=pd.DataFrame({'model':['Logistic Regression','Support Vector Classifier',
                            'DecisionTree Classifier','Random Forest Classifier','XGBoost'],
                    
                      'score':[acc_lr,acc_svc,acc_dt,acc_rfc,acc_xgb]})
Models
# Out:
#                        model      score
# 0        Logistic Regression  79.706223
# 1  Support Vector Classifier  75.454194
# 2    DecisionTree Classifier  79.396985
# 3   Random Forest Classifier  84.190182
# 4                    XGBoost  83.494395

# %% [raw]
#  We got our best model i.e. Random Forest classifier with the accuracy score of 84%. Here our model predicts 1091 true positive cases out of 1332 positive cases and 1087 true negative cases out of 1255 cases.
#  It predicts 241 false positive cases out of 1332 positive cases and 168 false negative cases out of 1255 cases.
#  It gives the f1 score of 85% for predicting 1 and 0.precision is 83% and recall is 87% for predicting 1
#
#  By compairing F1 score for different model, Random Forest gives 84% F1 value for predicting 1(yes) for churn

# %%
actual_predicted=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_rfc})

# %%
actual_predicted
# Out:
#       Actual  Predicted
# 5486       0          0
# 371        1          1
# 1221       0          0
# 1426       0          0
# 9010       1          1
# ...      ...        ...
# 7108       1          1
# 698        0          0
# 1570       0          0
# 1460       1          1
# 7092       1          1
#
# [2587 rows x 2 columns]

# %%
# Cross Validation

# %%
# now check for cross validation score as well as overfitting if exist

# %%
from sklearn.model_selection import cross_val_score

# %%
# Cross-Validation Logistic Regression
cvs_lr=cross_val_score(lr,x_,y_,cv=5)
print(cvs_lr.mean())
# Out:
# 0.786534884644032

# %%
# Cross-Validation SVC
cvs_svc=cross_val_score(svc,x_,y_,cv=5)
print(cvs_svc.mean())
# Out:
# 0.7554129862730952

# %%
# Cross-Validation DecisionTree Classifier
cvs_dt=cross_val_score(dt,x_,y_,cv=5)
print(cvs_dt.mean())
# Out:
# 0.7880831599666576

# %%
# Cross-Validation Random Forest Classifier
cvs_rfc=cross_val_score(rfc,x_,y_,cv=10)
print(cvs_rfc.mean())
# Out:
# 0.846646483334735

# %%
# Cross-Validation XGB Classifier
cvs_xgb=cross_val_score(xgb,x_,y_,cv=5)
print(cvs_xgb.mean())
# Out:
# [11:01:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:01:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:01:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
# Cross-Validation: RandomForestClassifier gives good accuracy about 84.6%
# difference between accuracy score and cv score is less in Random Forest and XGB

# %%
## hypertuning the model with GridSearchCV (using Random Forest)

# %%
parameters={'min_samples_leaf':[1,3,5],
            'max_depth':[4,6,8,10],
            'criterion':['gini','entropy'],
            'min_samples_split':[2,4,6,8,10],
             'n_estimators':[50,100]
           }

# %%
from sklearn.model_selection import GridSearchCV

# %%
gscv=GridSearchCV(RandomForestClassifier(),parameters)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 6, 8, 10],
#                          'min_samples_leaf': [1, 3, 5],
#                          'min_samples_split': [2, 4, 6, 8, 10],
#                          'n_estimators': [50, 100]})

# %%
parameters=gscv.best_params_

# %%
parameters
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
clf=RandomForestClassifier(criterion='entropy',max_depth=10,min_samples_leaf=1,min_samples_split=2,n_estimators=100)

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8)

# %%
clf_pred_rf=gscv.best_estimator_.predict(x_test)

# %%
print(accuracy_score(y_test,clf_pred_rf)*100)
print(confusion_matrix(y_test,clf_pred_rf))
print(classification_report(y_test,clf_pred_rf))
# Out:
# 82.48936992655585
# [[1038  294]
#  [ 159 1096]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.78      0.82      1332
#            1       0.79      0.87      0.83      1255
#
#     accuracy                           0.82      2587
#    macro avg       0.83      0.83      0.82      2587
# weighted avg       0.83      0.82      0.82      2587

# %%
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(gscv.best_estimator_,x_test,y_test)
plt.title('ROC_AUC plot')
plt.show()

# %%
actual_predicted=pd.DataFrame({'Actual':y_test,'Predicted':clf_pred_rf})

# %%
actual_predicted
# Out:
#       Actual  Predicted
# 5486       0          0
# 371        1          1
# 1221       0          1
# 1426       0          0
# 9010       1          1
# ...      ...        ...
# 7108       1          1
# 698        0          0
# 1570       0          0
# 1460       1          1
# 7092       1          1
#
# [2587 rows x 2 columns]

# %%
# Saving model
import joblib
joblib.dump(clf,'Customer Churn.pkl')
# Out:
# ['Customer Churn.pkl']

# %% [raw]
# Conclusion:
#
# By comparing the different model in this classification problem we can conclude that RF works better here after hypertunning 83% Accuracy.
# AUC  =91%
# and CV value is 85% .F1 score is 84%
