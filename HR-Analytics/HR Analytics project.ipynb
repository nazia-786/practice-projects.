# %% [raw]
# HR Analytics Project- Understanding the Attrition in HR
#
# Problem Statement:
#
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
#
# HR Analytics
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
# Attrition in HR
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
#
# Attrition affecting Companies
#
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from imblearn.over_sampling import SMOTE

# %%
df=pd.read_csv(r'C:\Users\91964\Desktop\nazia\datascience\Projects_DT\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# EDA analysis

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# All rows are integer type data and 9 are object type data

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#There is no missing value presents in the dataset

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [raw]
# ## Total rows are 1470 and total columns are 35, There is no missing values present in the dataset
#
# 1.Age : Mean=36.9 ,std=9 ,min=18 , max=60                         2.DailyRate: Mean=802 ,std=403 ,min=573 , max=102
# 3.DistanceFromHome: Mean=9.19 ,std=8.10 ,min=1,max=29             4.Education: Mean=2.91 ,std=1.02 ,min=1.0 , max=15
# 5.EmployeeCount: Mean=1 ,std=0 ,min=1,max=1                       6.EmployeeNumber: Mean=1024 ,std=602 ,min=1.0,max=2068
# 7 EnvironmentSatisfaction: Mean=2.72 ,std=1.09,min=1.0,max=4      8.HourlyRate: Mean=65.8,std=20.3 ,min=30,max=100
# 9.JobInvolvement:Mean=2.72 ,std=1.0 ,min=1,max=5                  10.JobLevel: Mean=2.06,std=1.10 ,min=1,max=5
# 11.RelationshipSatisfaction: Mean=2.7 ,std=1 ,min=1,max=4         12.StandardHours: Mean=80,std=0 ,min=80,max=80
# 13.StockOptionLevel: Mean=0.79 ,std=0.85 ,min=0.0,max=3           14.TotalWorkingYears: Mean=11.27 ,std=7.78,min=0,max=40
# 15.TrainingTimesLastYear: Mean=2.79 ,std=1.28 ,min=0,max=6        16.WorkLifeBalance :Mean=2.76,std=.7,min=1,max=4
# 17.YearsAtCompany: Mean=7 ,std=7 ,min=0,max=40                    18.YearsInCurrentRole: Mean=4.22 ,std=3.6,min=0,max=18
# 19.YearsSinceLastPromotion: Mean=2.18 ,std=3.22,min=0,max=15      20.YearsWithCurrManager:Mean=4.12,std=3.6,min=0,max=17

# %%
df.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
# Attrition : It is our target variable,here total count is 1470 and 2 unique values are there 0 and (yes and no).
#             It is a binary classification problem
# BusinessTravel:3 unique values are there
# Department:3 type are here
# EducationField: 6 unique values are there
# Gender: 2 values are there
# JobRole: there are 9 types of jobroles are there
# MaritalStatus:MaritalStatus has 3unique values
# Overtime: Overtime has 2 unique values
# Over18 :Over18 has only one unique value

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# total no of columns=35
# Total no of rows=1470
# All 35 columns are non-null and all are integer type except 9 columns that are having object type data
#  memory usage 4.1KB

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.sample(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1431   32        No      Travel_Rarely        801                   Sales
# 853    19        No      Travel_Rarely        645  Research & Development
# 576    27        No  Travel_Frequently        829                   Sales
# 863    33        No      Travel_Rarely        147         Human Resources
# 1462   39        No      Travel_Rarely        722                   Sales
# 248    37        No      Travel_Rarely       1017  Research & Development
# 776    20       Yes  Travel_Frequently        769                   Sales
# 905    29        No      Travel_Rarely        694  Research & Development
# 199    38        No      Travel_Rarely       1084  Research & Development
# 53     35        No         Non-Travel       1097  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 1431                 1          4         Marketing              1
# ...

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['Attrition']=df['Attrition'].replace({'No': 0,'Yes':1})

# %%
df['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
sns.histplot(x=df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Count'>

# %%
sns.distplot(df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='Density'>

# %%
# Looks class data is not balance so we need to balance our target variable witn 'upsampling' or 'downsampling' technique later

# %%
# Visualization

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
sns.histplot(x=df['BusinessTravel'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Count'>

# %% [raw]
# # in BusinessTravel feature Travel_Rarely person is high than Travel_Frequently and Non-Traveler

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='BusinessTravel',hue='Attrition',data=df)
plt.show()

# %%
# Both are categorical data(Attrition and BuinessTravel) so we can analyse it by cross-tabular way

# %%
pd.crosstab(columns=[df.Attrition],index=[df.BusinessTravel], margins=True,normalize='index')
# Out:
# Attrition                 0         1
# BusinessTravel
# Non-Travel         0.920000  0.080000
# Travel_Frequently  0.750903  0.249097
# Travel_Rarely      0.850431  0.149569
# All                0.838776  0.161224

# %%
# In the above plot we can see that in Non_Travel category,92% employee doesn't want to leave company
# In Travel_Frequently category 75% people don't want to leave company
# In Travel_Rarely category 85% people don't want to leave company

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
sns.histplot(x=df['Department'])
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Count'>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Department', hue='Attrition', data=df)
plt.show()

# %%
df.groupby(by='Department')['Attrition'].mean().sort_values(ascending=False)
# Out:
# Department
# Sales                     0.206278
# Human Resources           0.190476
# Research & Development    0.138398
# Name: Attrition, dtype: float64

# %%
df.groupby(by='Department')['Attrition'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('Attrition rate vs Department')
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.Department],margins=True,normalize='index')
# Out:
# Attrition                      0         1
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278
# All                     0.838776  0.161224

# %%
# here we can say that 80% of HumanResources employee don't want to leave company
                    #  86% of Research & Development employee don't want to leave company
                    #  79% of Sales employee don't want to leave company

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
plt.figure(figsize=(12,5))
sns.histplot(x=df['EducationField'])
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='Count'>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='EducationField', hue='Attrition', data=df)
plt.show()

# %%
df.groupby(by='EducationField')['Attrition'].mean().sort_values(ascending=False)
# Out:
# EducationField
# Human Resources     0.259259
# Technical Degree    0.242424
# Marketing           0.220126
# Life Sciences       0.146865
# Medical             0.135776
# Other               0.134146
# Name: Attrition, dtype: float64

# %%
df.groupby(by='EducationField')['Attrition'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('Attrition vs EducationField')
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.EducationField],margins=True,normalize='index')
# Out:
# Attrition                0         1
# EducationField
# Human Resources   0.740741  0.259259
# Life Sciences     0.853135  0.146865
# Marketing         0.779874  0.220126
# Medical           0.864224  0.135776
# Other             0.865854  0.134146
# Technical Degree  0.757576  0.242424
# All               0.838776  0.161224

# %%
# 74% Human Resources EducationField employees dont want to leave company 
# 85% Life Sciences EducationField employees dont want to leave company 
# 78% Marketing EducationField employees dont want to leave company

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='JobRole', hue='Attrition', data=df)
plt.show()

# %%
df.groupby(by='JobRole')['Attrition'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('Attrition vs JobRole')
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.JobRole],margins=True,normalize='index')
# Out:
# Attrition                         0         1
# JobRole
# Healthcare Representative  0.931298  0.068702
# Human Resources            0.769231  0.230769
# Laboratory Technician      0.760618  0.239382
# Manager                    0.950980  0.049020
# Manufacturing Director     0.931034  0.068966
# Research Director          0.975000  0.025000
# Research Scientist         0.839041  0.160959
# Sales Executive            0.825153  0.174847
# Sales Representative       0.602410  0.397590
# All                        0.838776  0.161224

# %%
## 93% Healthcare Representative employees dont want to leave company 
## 40% Sales Representative employees leave company

# %%
df['Gender'].value_counts().sort_values(ascending=False)
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Gender', hue='Attrition', data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.Gender],margins=True,normalize='index')
# Out:
# Attrition         0         1
# Gender
# Female     0.852041  0.147959
# Male       0.829932  0.170068
# All        0.838776  0.161224

# %%
# Gender
# chances of leaving organization is 18% for male employees
# chances of leaving organization is 14% for female employees

# %%
df['MaritalStatus'].value_counts().sort_values(ascending=False)
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='MaritalStatus', hue='Attrition', data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.MaritalStatus],margins=True,normalize='index')
# Out:
# Attrition             0         1
# MaritalStatus
# Divorced       0.899083  0.100917
# Married        0.875186  0.124814
# Single         0.744681  0.255319
# All            0.838776  0.161224

# %%
# MaritalStatus
# 90% divorced employee dont want to leave organization,however 25% single status employees attrition rate is high(1)

# %%
df['OverTime'].value_counts().sort_values(ascending=False)
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
plt.figure(figsize=(8,3))
sns.countplot(x='OverTime', hue='Attrition', data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.OverTime],margins=True,normalize='index')
# Out:
# Attrition         0         1
# OverTime
# No         0.895636  0.104364
# Yes        0.694712  0.305288
# All        0.838776  0.161224

# %%
# 30% OverTiming employee changes company

# %%
# For continuous data visualization

# %%
plt.figure(figsize=(30,10))
sns.violinplot(x='Age',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Age',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.regplot(x='Age',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.Age],margins=True,normalize='index')
# Out:
# Attrition         0         1
# Age
# 18         0.500000  0.500000
# 19         0.333333  0.666667
# 20         0.454545  0.545455
# 21         0.538462  0.461538
# 22         0.687500  0.312500
# 23         0.714286  0.285714
# 24         0.730769  0.269231
# 25         0.769231  0.230769
# 26         0.692308  0.307692
# 27         0.937500  0.062500
# 28         0.708333  0.291667
# 29         0.735294  0.264706
# 30         0.850000  0.150000
# 31         0.739130  0.260870
# 32         0.819672  0.180328
# 33         0.793103  0.206897
# 34         0.883117  0.116883
# 35         0.871795  0.128205
# 36         0.913043  0.086957
# 37         0.880000  0.120000
# 38         0.965517  0.034483
# 39         0.857143  0.142857
# 40         0.912281  0.087719
# 41         0.850000  0.150000
# 42         0.956522  0.043478
# 43         0.937500  0.062500
# 44         0.818182  0.181818
# 45         0.951220  0.048780
# 46         0.878788  0.121212
# 47         0.875000  0.125000
# ...

# %%
# we can see when age is increasing attrition rate is less.Means employee>=59 yrs of age don't want to leave company

# %%
plt.figure(figsize=(15,8))
sns.regplot(x='DailyRate',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.DailyRate],margins=True,normalize='index')
# Out:
# Attrition         0         1
# DailyRate
# 102        1.000000  0.000000
# 103        0.000000  1.000000
# 104        0.000000  1.000000
# 105        1.000000  0.000000
# 106        1.000000  0.000000
# ...             ...       ...
# 1495       1.000000  0.000000
# 1496       0.500000  0.500000
# 1498       1.000000  0.000000
# 1499       1.000000  0.000000
# All        0.838776  0.161224
#
# [887 rows x 2 columns]

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='HourlyRate',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.regplot(x='HourlyRate',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.HourlyRate],margins=True,normalize='index')
# Out:
# Attrition          0         1
# HourlyRate
# 30          1.000000  0.000000
# 31          0.866667  0.133333
# 32          0.833333  0.166667
# 33          0.842105  0.157895
# 34          0.583333  0.416667
# ...              ...       ...
# 97          0.857143  0.142857
# 98          0.892857  0.107143
# 99          0.800000  0.200000
# 100         0.736842  0.263158
# All         0.838776  0.161224
#
# [72 rows x 2 columns]

# %%
plt.figure(figsize=(20,5))
sns.regplot(x='EnvironmentSatisfaction',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='EnvironmentSatisfaction',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.EnvironmentSatisfaction],margins=True,normalize='index')
# Out:
# Attrition                       0         1
# EnvironmentSatisfaction
# 1                        0.746479  0.253521
# 2                        0.850174  0.149826
# 3                        0.863135  0.136865
# 4                        0.865471  0.134529
# All                      0.838776  0.161224

# %%
# when EnvironmentSatisfaction is increasing chances of leavivg organization is less and vice-versa

# %%
plt.figure(figsize=(20,5))
sns.regplot(x='JobInvolvement',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='JobInvolvement',y='Attrition',data=df)
plt.show()

# %%
# when JobInvolvement is increasing chances of leavivg organization is less and vice-versa

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='JobLevel',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='JobLevel',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.JobLevel],margins=True,normalize='index')
# Out:
# Attrition         0         1
# JobLevel
# 1          0.736648  0.263352
# 2          0.902622  0.097378
# 3          0.853211  0.146789
# 4          0.952830  0.047170
# 5          0.927536  0.072464
# All        0.838776  0.161224

# %%
# people with 4 JobLevel has 95% 0 attrition rate 0.04% has 1 attrition rate

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='RelationshipSatisfaction',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.RelationshipSatisfaction],margins=True,normalize='index')
# Out:
# Attrition                        0         1
# RelationshipSatisfaction
# 1                         0.793478  0.206522
# 2                         0.851485  0.148515
# 3                         0.845316  0.154684
# 4                         0.851852  0.148148
# All                       0.838776  0.161224

# %%
# people with 4 RelationshipSatisfaction has 85% 0 attrition rate and 0.14% has 1 attrition rate

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='StockOptionLevel',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.StockOptionLevel],margins=True,normalize='index')
# Out:
# Attrition                0         1
# StockOptionLevel
# 0                 0.755943  0.244057
# 1                 0.906040  0.093960
# 2                 0.924051  0.075949
# 3                 0.823529  0.176471
# All               0.838776  0.161224

# %%
# StockOptionLevel 2, 92% employees attrition rate is 0

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='TotalWorkingYears',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='TotalWorkingYears',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.TotalWorkingYears],margins=True,normalize='index')
# Out:
# Attrition                 0         1
# TotalWorkingYears
# 0                  0.545455  0.454545
# 1                  0.506173  0.493827
# 2                  0.709677  0.290323
# 3                  0.785714  0.214286
# 4                  0.809524  0.190476
# 5                  0.818182  0.181818
# 6                  0.824000  0.176000
# 7                  0.777778  0.222222
# 8                  0.844660  0.155340
# 9                  0.895833  0.104167
# 10                 0.876238  0.123762
# 11                 0.805556  0.194444
# 12                 0.895833  0.104167
# 13                 0.916667  0.083333
# 14                 0.870968  0.129032
# 15                 0.875000  0.125000
# 16                 0.918919  0.081081
# 17                 0.909091  0.090909
# 18                 0.851852  0.148148
# 19                 0.863636  0.136364
# 20                 0.933333  0.066667
# 21                 0.970588  0.029412
# 22                 0.904762  0.095238
# ...

# %%
#  for all employees whose TotalWorkingYears is more, 83% of them dont want to move

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='TrainingTimesLastYear',y='Attrition',data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='TrainingTimesLastYear',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.TrainingTimesLastYear],margins=True,normalize='index')
# Out:
# Attrition                     0         1
# TrainingTimesLastYear
# 0                      0.722222  0.277778
# 1                      0.873239  0.126761
# 2                      0.820841  0.179159
# 3                      0.859470  0.140530
# 4                      0.788618  0.211382
# 5                      0.882353  0.117647
# 6                      0.907692  0.092308
# All                    0.838776  0.161224

# %%
# 83% overall level of TraininTimeLastYear employee dont want to leave company

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='WorkLifeBalance',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.WorkLifeBalance],margins=True,normalize='index')
# Out:
# Attrition               0         1
# WorkLifeBalance
# 1                0.687500  0.312500
# 2                0.831395  0.168605
# 3                0.857783  0.142217
# 4                0.823529  0.176471
# All              0.838776  0.161224

# %%
# WorkLifeBalance : 68% of level 1 worklifeBalance employees dont want to change their company

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='YearsAtCompany',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.YearsAtCompany],margins=True,normalize='index')
# Out:
# Attrition              0         1
# YearsAtCompany
# 0               0.636364  0.363636
# 1               0.654971  0.345029
# 2               0.787402  0.212598
# 3               0.843750  0.156250
# 4               0.827273  0.172727
# 5               0.892857  0.107143
# 6               0.881579  0.118421
# 7               0.877778  0.122222
# 8               0.887500  0.112500
# 9               0.902439  0.097561
# 10              0.850000  0.150000
# 11              0.937500  0.062500
# 12              1.000000  0.000000
# 13              0.916667  0.083333
# 14              0.888889  0.111111
# 15              0.950000  0.050000
# 16              0.916667  0.083333
# 17              0.888889  0.111111
# 18              0.923077  0.076923
# 19              0.909091  0.090909
# 20              0.962963  0.037037
# 21              0.928571  0.071429
# 22              0.933333  0.066667
# 23              0.500000  0.500000
# 24              0.833333  0.166667
# ...

# %%
#  for all employees whose YearsAtCompany is more, 83% of them dont want to move

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='YearsInCurrentRole',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.YearsInCurrentRole],margins=True,normalize='index')
# Out:
# Attrition                  0         1
# YearsInCurrentRole
# 0                   0.700820  0.299180
# 1                   0.807018  0.192982
# 2                   0.817204  0.182796
# 3                   0.881481  0.118519
# 4                   0.855769  0.144231
# 5                   0.972222  0.027778
# 6                   0.945946  0.054054
# 7                   0.860360  0.139640
# 8                   0.921348  0.078652
# 9                   0.910448  0.089552
# 10                  0.931034  0.068966
# 11                  1.000000  0.000000
# 12                  0.900000  0.100000
# 13                  0.928571  0.071429
# 14                  0.909091  0.090909
# 15                  0.750000  0.250000
# 16                  1.000000  0.000000
# 17                  1.000000  0.000000
# 18                  1.000000  0.000000
# All                 0.838776  0.161224

# %%
#  for all employees whose YearsInCurrentRole is more, 83% of them dont want to change

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='YearsSinceLastPromotion',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.YearsSinceLastPromotion],margins=True,normalize='index')
# Out:
# Attrition                       0         1
# YearsSinceLastPromotion
# 0                        0.810671  0.189329
# 1                        0.862745  0.137255
# 2                        0.830189  0.169811
# 3                        0.826923  0.173077
# 4                        0.918033  0.081967
# 5                        0.955556  0.044444
# 6                        0.812500  0.187500
# 7                        0.789474  0.210526
# 8                        1.000000  0.000000
# 9                        0.764706  0.235294
# 10                       0.833333  0.166667
# 11                       0.916667  0.083333
# 12                       1.000000  0.000000
# 13                       0.800000  0.200000
# 14                       0.888889  0.111111
# 15                       0.769231  0.230769
# All                      0.838776  0.161224

# %%
# YearsSinceLastPromotion : 83% employee dont want to move or change

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='YearsWithCurrManager',y='Attrition',data=df)
plt.show()

# %%
pd.crosstab(columns=[df.Attrition],index=[df.YearsWithCurrManager],margins=True,normalize='index')
# Out:
# Attrition                    0         1
# YearsWithCurrManager
# 0                     0.676806  0.323194
# 1                     0.855263  0.144737
# 2                     0.854651  0.145349
# 3                     0.866197  0.133803
# 4                     0.887755  0.112245
# 5                     0.870968  0.129032
# 6                     0.862069  0.137931
# 7                     0.856481  0.143519
# 8                     0.906542  0.093458
# 9                     0.906250  0.093750
# 10                    0.888889  0.111111
# 11                    0.954545  0.045455
# 12                    1.000000  0.000000
# 13                    1.000000  0.000000
# 14                    0.600000  0.400000
# 15                    1.000000  0.000000
# 16                    1.000000  0.000000
# 17                    1.000000  0.000000
# All                   0.838776  0.161224

# %%
# YearsWithCurrManager : 83% overall employee dont want to move or change company

# %%
# Thogh can not conclude any single feature so we combine it and measure correlation by heatmap

# %%
plt.figure(figsize=(20,15))
corr=df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber           -0.010145  -0.010577  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# ...

# %%
#from some columns have Nan values we will drop them

# %%
df['Over18'].value_counts().sort_values(ascending=False)
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df['StandardHours'].value_counts().sort_values(ascending=False)
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %%
df['EmployeeNumber'].value_counts().sort_values(ascending=False)
# Out:
# 2048    1
# 21      1
# 2051    1
# 4       1
# 5       1
#        ..
# 2040    1
# 2041    1
# 2044    1
# 2045    1
# 2046    1
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %%
df['EmployeeCount'].value_counts().sort_values(ascending=False)
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
df=df.drop(columns=['EmployeeCount','EmployeeNumber','StandardHours','Over18'],axis=1)

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
# ...

# %%
plt.figure(figsize=(20,15))
corr=df.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# JobSatisfaction          -0.004892  -0.103481   0.030571         -0.003669
# MonthlyIncome             0.497855  -0.159840   0.007707         -0.017014
# ...

# %%
corr['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# DistanceFromHome            0.077924
# NumCompaniesWorked          0.043494
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# HourlyRate                 -0.006846
# PercentSalaryHike          -0.013478
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# StockOptionLevel           -0.137145
# YearsWithCurrManager       -0.156199
# Age                        -0.159205
# MonthlyIncome              -0.159840
# YearsInCurrentRole         -0.160545
# JobLevel                   -0.169105
# TotalWorkingYears          -0.171063
# Name: Attrition, dtype: float64

# %%
corr['Age'].sort_values(ascending=False)
# Out:
# Age                         1.000000
# TotalWorkingYears           0.680381
# JobLevel                    0.509604
# MonthlyIncome               0.497855
# YearsAtCompany              0.311309
# NumCompaniesWorked          0.299635
# YearsSinceLastPromotion     0.216513
# YearsInCurrentRole          0.212901
# Education                   0.208034
# YearsWithCurrManager        0.202089
# RelationshipSatisfaction    0.053535
# StockOptionLevel            0.037510
# JobInvolvement              0.029820
# MonthlyRate                 0.028051
# HourlyRate                  0.024287
# DailyRate                   0.010661
# EnvironmentSatisfaction     0.010146
# PercentSalaryHike           0.003634
# PerformanceRating           0.001904
# DistanceFromHome           -0.001686
# JobSatisfaction            -0.004892
# TrainingTimesLastYear      -0.019621
# WorkLifeBalance            -0.021490
# Attrition                  -0.159205
# Name: Age, dtype: float64

# %%
corr['YearsAtCompany'].sort_values(ascending=False)
# Out:
# YearsAtCompany              1.000000
# YearsWithCurrManager        0.769212
# YearsInCurrentRole          0.758754
# TotalWorkingYears           0.628133
# YearsSinceLastPromotion     0.618409
# JobLevel                    0.534739
# MonthlyIncome               0.514285
# Age                         0.311309
# Education                   0.069114
# RelationshipSatisfaction    0.019367
# StockOptionLevel            0.015058
# WorkLifeBalance             0.012089
# DistanceFromHome            0.009508
# TrainingTimesLastYear       0.003569
# PerformanceRating           0.003435
# EnvironmentSatisfaction     0.001458
# JobSatisfaction            -0.003803
# HourlyRate                 -0.019582
# JobInvolvement             -0.021355
# MonthlyRate                -0.023655
# DailyRate                  -0.034055
# PercentSalaryHike          -0.035991
# NumCompaniesWorked         -0.118421
# Attrition                  -0.134392
# Name: YearsAtCompany, dtype: float64

# %% [raw]
# # Outcome of correlation with features
#
# All features are related with target.
# but all features and target variables are not strongly correlated.
#
# 1.Age is 68% correlated with TotalWorkingYears
# 2.Age is 50% correlated with JobLevel
# 3.Age is 49% correlated with MonthlyIncome
#
# 4.YearsAtCompany 77% correlated with YearsWithCurrManager
# 5.YearsAtCompany 76% correlated with YearsInCurrentRole
# 6.YearsAtCompany 62% correlated with TotalWorkingYears
# 7.YearsAtCompany 61% correlated with YearsSinceLastPromotion
# 8.YearsAtCompany 53% correlated with JobLevel
# 9.YearsAtCompany 51% correlated with MonthlyIncome
# 10.MonthlyIncome 95% correlated with JobLevel
#
# Overall correlation is less we will move to next step.

# %%
df.skew().sort_values(ascending=False)
# Out:
# YearsSinceLastPromotion     1.984290
# PerformanceRating           1.921883
# Attrition                   1.844366
# YearsAtCompany              1.764529
# MonthlyIncome               1.369817
# TotalWorkingYears           1.117172
# NumCompaniesWorked          1.026471
# JobLevel                    1.025401
# StockOptionLevel            0.968980
# DistanceFromHome            0.958118
# YearsInCurrentRole          0.917363
# YearsWithCurrManager        0.833451
# PercentSalaryHike           0.821128
# TrainingTimesLastYear       0.553124
# Age                         0.413286
# MonthlyRate                 0.018578
# DailyRate                  -0.003519
# HourlyRate                 -0.032311
# Education                  -0.289681
# RelationshipSatisfaction   -0.302828
# EnvironmentSatisfaction    -0.321654
# JobSatisfaction            -0.329672
# JobInvolvement             -0.498419
# WorkLifeBalance            -0.552480
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
var=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']
for i in var:
    
    df[i]=lab_enc.fit_transform (df[i])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2               1                        2       0  ...
# 1          1               1                        3       1  ...
# 2          2               4                        4       1  ...
# 3          4               1                        4       0  ...
# 4          1               3                        1       1  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
x=df.drop(columns=['Attrition'],axis=1)
y=df['Attrition']

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=30:
        ax=plt.subplot(5,6,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
# Outlier checking

plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=30:
        ax=plt.subplot(5,6,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore

# %%
(np.abs(zscore(x))<3).all()
# Out:
# False

# %%
x.shape
# Out:
# (1470, 30)

# %%
z_score=zscore(df[['TrainingTimesLastYear','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','PerformanceRating','StockOptionLevel','TotalWorkingYears','MonthlyIncome','NumCompaniesWorked']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1387, 31)

# %%
x=df.drop(columns=['Attrition'],axis=1)
y=df['Attrition']

# %%
x.shape,y.shape
# Out:
# ((1387, 30), (1387,))

# %%
(np.abs(zscore(x))<3).all()
# Out:
# False

# %%
z_score=zscore(df[['TrainingTimesLastYear','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','PerformanceRating','StockOptionLevel','TotalWorkingYears','MonthlyIncome','NumCompaniesWorked']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (1304, 31)

# %%
x=df.drop(columns=['Attrition'],axis=1)
y=df['Attrition']

# %%
(np.abs(zscore(x))<3).all(axis=1)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
# outliers are removed and all the points are falls in between +/-3

# %%
data_loss=((1470-1304)/1470)*100
data_loss
# Out:
# 11.292517006802722

# %%
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
pca=PCA()

# %%
pca.fit_transform(x_scaled)
# Out:
# array([[ 0.17676876,  1.03353792, -2.17342844, ..., -0.88156105,
#         -0.00577676,  0.03916048],
#        [ 1.31417381, -1.1316487 ,  2.21974396, ..., -0.62615091,
#          0.06684895,  0.22706607],
#        [-2.67969983,  1.34472196, -0.01556645, ...,  0.22930903,
#         -0.07708279,  0.05940892],
#        ...,
#        [-0.87188309, -0.07933635,  2.1695401 , ..., -0.53616344,
#          0.40800754,  0.06709557],
#        [ 1.80161807, -0.32290134, -1.26515541, ...,  0.1972755 ,
#         -0.31211879,  0.01183624],
#        [-0.83301157,  0.21630205, -0.16243163, ..., -0.32472557,
#          0.04914227,  0.35618166]])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('principal components')
plt.ylabel('varience covered')
plt.title('pca')
plt.show()

# %%
pca=PCA(n_components=24)
new_pcomp=pca.fit_transform(x_scaled)

# %%
princi_comp=pd.DataFrame(new_pcomp,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20','PC21','PC22','PC23','PC24'])

# %%
princi_comp
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     0.176769  1.033538 -2.173428  0.786248 -0.058953  0.876893 -2.341466
# 1     1.314174 -1.131649  2.219744  2.205434 -0.161895  0.775475  0.541808
# 2    -2.679700  1.344722 -0.015566 -0.292442 -1.332587  0.288171  0.335490
# 3    -0.330920 -0.896310 -0.996543 -0.874541 -0.420812  1.258312 -0.530572
# 4    -1.818982  0.634397  0.103361 -1.401301 -0.749684 -0.607704  0.935372
# ...        ...       ...       ...       ...       ...       ...       ...
# 1299 -0.159697  0.728323  0.980998 -0.597259 -0.292256  0.402833 -0.729125
# 1300  1.815475  0.180229  0.631327 -0.839091 -1.003632  1.419248  3.384958
# 1301 -0.871883 -0.079336  2.169540  1.698929  0.241676 -0.860732 -1.580844
# 1302  1.801618 -0.322901 -1.265155  0.166534  0.097838 -0.191884 -0.291758
# 1303 -0.833012  0.216302 -0.162432 -0.979572 -0.829196 -1.584069  0.566512
#
# ...

# %%
# Skewness checking

plt.figure(figsize=(20,20))
plotnumber=1

for column in princi_comp:
    if plotnumber<=24:
        ax=plt.subplot(6,4,plotnumber)
        sns.distplot(princi_comp[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
# Outlier checking

plt.figure(figsize=(20,20))
plotnumber=1

for column in princi_comp:
    if plotnumber<=24:
        ax=plt.subplot(4,6,plotnumber)
        sns.boxplot(princi_comp[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
(np.abs(zscore(princi_comp))<3).all(axis=1)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
# Now HR-Analytics Dataset is ready for training

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(princi_comp,y,test_size=0.25,random_state=441)

# %%
# Handling Imbalanced Dataset

# %%
# Over Sampling for minority or Under Sampling for majority class
# Here we will do over-sampling as no of observation is less.
# Here we use SMOTE(Synthetic Minority Oversampling Technique)

# %%
oversampler=SMOTE(random_state=441)
x_train_ns,y_train_ns=oversampler.fit_resample(x_train,y_train)

# %%
x_train_ns.shape,y_train_ns.shape,x_test.shape,y_test.shape
# Out:
# ((1618, 24), (1618,), (326, 24), (326,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# though we have done oversampling,there is a chance of getting high value of
# accuracy so we consider confusion matrix,precion ,recall and f1score

# %%
lr=LogisticRegression()
lr.fit(x_train_ns,y_train_ns)
y_pred_lr=lr.predict(x_test)
acc_lr=accuracy_score(y_test,y_pred_lr)*100
acc_lr
# Out:
# 73.92638036809815

# %%
print(confusion_matrix(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# [[205  67]
#  [ 18  36]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.83       272
#            1       0.35      0.67      0.46        54
#
#     accuracy                           0.74       326
#    macro avg       0.63      0.71      0.64       326
# weighted avg       0.82      0.74      0.77       326

# %%
# SUPPORT VECTOR CLASSIFIER
from sklearn.svm import SVC 
svc=SVC()
svc.fit(x_train_ns,y_train_ns)
y_pred_svc=svc.predict(x_test)
acc_svc=accuracy_score(y_test,y_pred_svc)*100
acc_svc
# Out:
# 82.20858895705521

# %%
print(confusion_matrix(y_test,y_pred_svc))
print(classification_report(y_test,y_pred_svc))
# Out:
# [[246  26]
#  [ 32  22]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       272
#            1       0.46      0.41      0.43        54
#
#     accuracy                           0.82       326
#    macro avg       0.67      0.66      0.66       326
# weighted avg       0.81      0.82      0.82       326

# %%
# DECISIONTREE CLASSIFIER

dt=DecisionTreeClassifier()
dt.fit(x_train_ns,y_train_ns)
y_pred_dt=dt.predict(x_test)
acc_dt=accuracy_score(y_test,y_pred_dt)*100
acc_dt
# Out:
# 74.5398773006135

# %%
print(confusion_matrix(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# [[219  53]
#  [ 30  24]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       272
#            1       0.31      0.44      0.37        54
#
#     accuracy                           0.75       326
#    macro avg       0.60      0.62      0.60       326
# weighted avg       0.79      0.75      0.76       326

# %%
# RANDOM FOREST CLASSIFIER

rfc=RandomForestClassifier()
rfc.fit(x_train_ns,y_train_ns)
y_pred_rfc=rfc.predict(x_test)
acc_rfc=accuracy_score(y_test,y_pred_rfc)*100
acc_rfc
# Out:
# 81.90184049079755

# %%
print(confusion_matrix(y_test,y_pred_rfc))
print(classification_report(y_test,y_pred_rfc))
# Out:
# [[254  18]
#  [ 41  13]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.90       272
#            1       0.42      0.24      0.31        54
#
#     accuracy                           0.82       326
#    macro avg       0.64      0.59      0.60       326
# weighted avg       0.79      0.82      0.80       326

# %%
# KNN CLASSIFIER

knn=KNeighborsClassifier()
knn.fit(x_train_ns,y_train_ns)
y_pred_knn=knn.predict(x_test)
acc_knn=accuracy_score(y_test,y_pred_knn)*100
acc_knn
# Out:
# 67.79141104294479

# %%
print(confusion_matrix(y_test,y_pred_knn))
print(classification_report(y_test,y_pred_knn))
# Out:
# [[185  87]
#  [ 18  36]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.68      0.78       272
#            1       0.29      0.67      0.41        54
#
#     accuracy                           0.68       326
#    macro avg       0.60      0.67      0.59       326
# weighted avg       0.81      0.68      0.72       326

# %%
# XG Boost
from xgboost import XGBClassifier
xgb=XGBClassifier(objective='binary:logistic')
xgb.fit(x_train_ns,y_train_ns)
y_pred_xgb=knn.predict(x_test)
acc_xgb=accuracy_score(y_test,y_pred_xgb)*100
acc_xgb
# Out:
# [09:26:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 67.79141104294479

# %%
print(confusion_matrix(y_test,y_pred_knn))
print(classification_report(y_test,y_pred_knn))
# Out:
# [[185  87]
#  [ 18  36]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.68      0.78       272
#            1       0.29      0.67      0.41        54
#
#     accuracy                           0.68       326
#    macro avg       0.60      0.67      0.59       326
# weighted avg       0.81      0.68      0.72       326

# %%
# Model Evaluation

Models=pd.DataFrame({'model':['Logistic Regression','Support Vector Classifier',
                            'DecisionTree Classifier','Random Forest Classifier','Kneighbors Clasifier','XGBoost'],
                    
                      'score':[acc_lr,acc_svc,acc_dt,acc_rfc,acc_knn,acc_xgb]})
Models
# Out:
#                        model      score
# 0        Logistic Regression  73.926380
# 1  Support Vector Classifier  82.208589
# 2    DecisionTree Classifier  74.539877
# 3   Random Forest Classifier  81.901840
# 4       Kneighbors Clasifier  67.791411
# 5                    XGBoost  67.791411

# %% [raw]
# # We got our best model i.e. Random Forest classifier with the accuracy score of 82%. Here our model predicts 257 true positive cases out of 272 positive cases and 15 true negative cases out of 54 cases.
#  It predicts 18 false positive cases out of 272 positive cases and 41 false negative cases out of 54 cases. It gives the f1
#  score of 36% for predicting 1.precision is 42% and recall is 24%
#
#  By compairing F1 score for different model, linear regression gives 46% F1 value to predict 1(yes) for attrition

# %%
# Cross Validation

# %%
# now check for cross validation score as well as overfitting if exist

# %%
from sklearn.model_selection import cross_val_score

# %%
# Cross-Validation Logistic Regression
cvs_lr=cross_val_score(lr,princi_comp,y,cv=5)
print(cvs_lr.mean())
# Out:
# 0.8650309460654289

# %%
# Cross-Validation SVC
cvs_svc=cross_val_score(svc,princi_comp,y,cv=5)
print(cvs_svc.mean())
# Out:
# 0.8550751547303271

# %%
# Cross-Validation DecisionTree Classifier
cvs_dt=cross_val_score(dt,princi_comp,y,cv=5)
print(cvs_dt.mean())
# Out:
# 0.7699498968464485

# %%
# Cross-Validation KNN
cvs_knn=cross_val_score(knn,princi_comp,y,cv=5)
print(cvs_knn.mean())
# Out:
# 0.8374329501915708

# %%
# Cross-Validation Random Forest Classifier
cvs_rfc=cross_val_score(rfc,princi_comp,y,cv=10)
print(cvs_rfc.mean())
# Out:
# 0.8489371697005283

# %%
# Cross-Validation XGB Classifier
cvs_xgb=cross_val_score(xgb,princi_comp,y,cv=5)
print(cvs_xgb.mean())
# Out:
# [09:50:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:50:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
# Cross-Validation: XGB, Logistic regression gives good accuracy about 86%

# %%
from sklearn.model_selection import GridSearchCV

# %%
## hypertuning the model with GridSearchCV (using xgb)

# %%
param_grid={'learning_rate':[1,0.5,0.1,0.01],
            'max_depth':[3,5,7,9,11],
            'n_estimators':[10,20,30,40,100,200]
           }

# %%
grid=GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid)

# %%
grid.fit(x_train,y_train)
# Out:
# [10:06:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:06:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:06:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
best_parameter=grid.best_params_

# %%
best_parameter
# Out:
# {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}

# %%
clf=XGBClassifier(learning_rate= 0.1, max_depth= 7, n_estimators= 200)

# %%
clf.fit(x_train,y_train)
# Out:
# [10:10:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=7, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred=clf.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred)*100)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 84.04907975460122
# [[261  11]
#  [ 41  13]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       272
#            1       0.54      0.24      0.33        54
#
#     accuracy                           0.84       326
#    macro avg       0.70      0.60      0.62       326
# weighted avg       0.81      0.84      0.81       326

# %%
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(grid.best_estimator_,x_test,y_test)
plt.title('ROC_AUC plot')
plt.show()

# %%
#BGBoost give accuracy 84% after tunning and AUC is 75%

# %%
## hypertuning the model with GridSearchCV (using Random Forest)

# %%
parameters={'min_samples_leaf':[1,5,10,15,20],
            'max_depth':[4,5,6,7,8,9,10],
            'criterion':['gini','entropy'],
            'min_samples_split':[2,4,6,8,10,12,14],
             'n_estimators':[50,100,150,200,250]
           }

# %%
gscv=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_leaf': [1, 5, 10, 15, 20],
#                          'min_samples_split': [2, 4, 6, 8, 10, 12, 14],
#                          'n_estimators': [50, 100, 150, 200, 250]})

# %%
parameters=gscv.best_params_

# %%
parameters
# Out:
# {'criterion': 'gini',
#  'max_depth': 9,
#  'min_samples_leaf': 1,
#  'min_samples_split': 8,
#  'n_estimators': 50}

# %%
clf=RandomForestClassifier(criterion='entropy',max_depth=10,min_samples_leaf=1,min_samples_split=14,n_estimators=250)

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, min_samples_split=14,
#                        n_estimators=250)

# %%
clf_pred=gscv.best_estimator_.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred)*100)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 84.04907975460122
# [[261  11]
#  [ 41  13]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       272
#            1       0.54      0.24      0.33        54
#
#     accuracy                           0.84       326
#    macro avg       0.70      0.60      0.62       326
# weighted avg       0.81      0.84      0.81       326

# %%
plot_roc_curve(gscv.best_estimator_,x_test,y_test)
plt.title('ROC_AUC plot')
plt.show()

# %%
# we get 84% accuracy and AUC 69% for Random Forest classifier after hypertunning

# %%
## hypertuning the model with GridSearchCV (using Logistic Regression)

# %%
param_grid={'penalty':['l2']
           }

# %%
grid_search_lr=GridSearchCV(estimator=lr,param_grid=param_grid)

# %%
grid_search_lr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(), param_grid={'penalty': ['l2']})

# %%
clf=LogisticRegression(penalty='l2')

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
clf_pred=grid_search.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred_lr)*100)
print(confusion_matrix(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# 87.11656441717791
# [[264   8]
#  [ 34  20]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       272
#            1       0.71      0.37      0.49        54
#
#     accuracy                           0.87       326
#    macro avg       0.80      0.67      0.71       326
# weighted avg       0.86      0.87      0.85       326

# %%
plot_roc_curve(grid_search_lr,x_test,y_test)
plt.title('ROC_AUC plot')
plt.show()

# %%
# logistic regression gives accuracy 87% , F1 value is 49% for predicting 1(yes).AUC 78%

# %%
# Saving model
import joblib
joblib.dump(grid_search_lr,'HR Analytics.pkl')
# Out:
# ['HR Analytics.pkl']

# %% [raw]
# Conclusion:
#
# By comparing the different model in this classification problem we can conclude that Logistic Regression works better here after hypertunning 87% Accuracy.
# AUC  =78%
# and CV value is 87% .F1 score is 49% for pedicting 1(yes)
