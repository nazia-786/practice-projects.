# %% [raw]
# Evaluation Project - 3
#
# Avacado Project
#
# Problem Statement:
#
# Avocado is a fruit consumed by people heavily in the United States.
#
# Content
#
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold
#
#
# Inspiration /Label
#
# The dataset can be seen in two angles to find the region and find the average price .
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\91964\Desktop\nazia\datascience\Projects_DT\avocado.csv')

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
# There is no missing value present in the dataset

# %%
df.drop_duplicates(inplace=True)

# %%
#if any duplicate entry then dropping it

# %%
## EDA Analysis of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 2.1+ MB

# %% [raw]
# # Total rows= 18249
#   Total columns= 14
#
#  1. Unnamed is integer type
#  2. Date is object type
#  3. AveragePrice is float type
#  4. Total Volume is float type
#  5. 4046 is also float type
#  6. 4770 is float type
#  7. 4225 is float type
#  8. Total Bags is float type
#  9. Small Bags is float type
#  10.Large Bags is float type
#  11.XLarge Bags is float type
#  12.type is object type
#  13.year is integer type
#  14.region is object type
#
#  dtypes: 9 columns are float64 ,
#          2 columns are int64,
#          3 columns are object
#
#  memory usage is 1.9 +MB

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [raw]
# ## Total rows are 18249 and total columns are 14
# All are continuous data
# 1.Unnamed:O : Here it is like index column where min is 0 and max is 52.we will drop it
# 2.AveragePrice : Mean=1.4 ,std=3.453545e+06 ,min=0.44 , max=3.25
# 3.Total Volume : Mean=8.506440e+05 ,std=14.8 ,min=8.456000e+01 , max=6.250565e+07
# 4.4046: Mean=2.930084e+05 ,std=1.264989e+06 ,min=0.0 , max=2.274362e+07
# 5.4225: Mean=2.951546e+05 ,std=1.204120e+06 ,min=0.0 , max=2.047057e+07
# 6.4770: Mean=2.283974e+04 ,std=1.074641e+05 ,min=0.0 , max=2.546439e+06
# 7.Total Bags:Mean=2.396392e+05 ,std=9.862424e+05 ,min=0.00 , max=1.937313e+07
# 8.Small Bags:Mean=1.821947e+05 ,std=7.461785e+05 ,min=0.00 , max=1.338459e+07
# 9.Large Bags:Mean=5.433809e+04 ,std=2.439660e+05 ,min=0.00 , max=5.719097e+06
# 10.XLarge Bags:Mean=3106.426507 ,std=17692.894652 ,min=0.00 , max=551693.650000
# 11.year: Mean=2016 ,std=0.9399 ,min=2015 , max=2018
#
# AveragePrice: It is outcome or target variable.It is continuous data we consider it as output for regression problem

# %%
df.describe(include='O')
# Out:
#               Date          type              region
# count        18249         18249               18249
# unique         169             2                  54
# top     2016-02-21  conventional  HarrisburgScranton
# freq           108          9126                 338

# %% [raw]
# # Categorical Data
# No missing data is presents
# 1.Date: 169 unique value is presents,frequency is 108
# 2.type: 2 unique value is presents,frequency is 9126
# 3.region: 54 unique value is presents,frequency is 338
#  Region: It is our outcome or target variable for classification problem

# %%
df.drop(columns='Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
# Here Date is object dtype we convert it as day and month and will drop it.

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date'].value_counts()
# Out:
# 2016-10-23    108
# 2016-04-03    108
# 2017-01-08    108
# 2016-02-14    108
# 2017-07-16    108
#              ...
# 2017-07-02    108
# 2015-05-24    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: Date, Length: 169, dtype: int64

# %%
df['Day']=df['Date'].dt.day

# %%
df['Day']
# Out:
# 0        27
# 1        20
# 2        13
# 3         6
# 4        29
#          ..
# 18244     4
# 18245    28
# 18246    21
# 18247    14
# 18248     7
# Name: Day, Length: 18249, dtype: int64

# %%
df['Month']=df['Date'].dt.month

# %%
df['Month']
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        11
#          ..
# 18244     2
# 18245     1
# 18246     1
# 18247     1
# 18248     1
# Name: Month, Length: 18249, dtype: int64

# %%
df=df.drop(columns='Date',axis=1)

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df['region'].nunique()
# Out:
# 54

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=df['region'])
plt.xticks(rotation=90)
plt.show()

# %%
# there are 54 unique regions all having all most same avacado counts except westTexNewMexico which is slight less

# %%
plt.figure(figsize=(20,6))
sns.stripplot(x=df['region'],y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='AveragePrice'>

# %%
# AveragePrice of avacado is almost same in all regions

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='year',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
# avacado count is less in 2018 and in 2017 is high means price and sale is high on year 2017 than other year

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='year',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
# Averageprice of avacado is more in the year of 2017 respectively other years

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Day',data=df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='count'>

# %%
# Avacado count is almost high(in average) in whole month but in some day's (2nd,9th,16th,23rd,30 and 31) it is less

# %%
plt.figure(figsize=(20,6))
sns.stripplot(x=df['Day'],y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='AveragePrice'>

# %%
# Averageprice of Avacado is almost high(in average) in whole month

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Month',data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
#Average count of avacado is high on each month(more than average)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Month',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [raw]
# # AveragePrice of avacado is started increasing from the month of june and maximum in the month of september and october
#   and started decreasing after that

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='type',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
# type of avacado count is almost same

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x='type',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
# Averageprice of avacado is more high for organic type than conventional type

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Total Volume',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Total Volume',y='AveragePrice',hue='type',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %% [raw]
# #Average price of organic avacado is very high with total volume is zero .
# For conventional avacado price is less with good total volume

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Total Volume',y='Total Bags',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Total Bags'>

# %%
#Total Volume is increases with Total Bags

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Total Volume',y='Total Bags',hue='type',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Total Bags'>

# %%
# No of total bags is increases with increasing value of Total Volume for conventional avacado

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Total Volume',y='Total Bags',hue='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Total Bags'>

# %%
# AveragePrice is high when total no of bag and total volume of avacado is less.

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Small Bags',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='AveragePrice'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Total Volume',y='Small Bags',hue='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Small Bags'>

# %%
#small bag has high avg. price

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='Large Bags',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='AveragePrice'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Total Volume',y='Large Bags',hue='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Large Bags'>

# %%
# when no of large bag increases with increasing total volume the average price is increases

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='region',y='AveragePrice',hue='type',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# average price of organic avacado is much higher than conventional type in every region

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df['4046'],df['4225'],hue=df['AveragePrice'],data=df)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='4225'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df['4046'],df['4770'],hue=df['AveragePrice'],data=df)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='4770'>

# %%
variable=df[['4046','4770','4225']].groupby(df.year).sum()
variable.plot(kind='bar',figsize=(10,5),fontsize=8)
plt.xlabel('types of PLU sold')
plt.ylabel('year')
plt.show()

# %%
# In every year sale of 4225 is more than other PLU

# %%
variable=df[['4046','4770','4225']].groupby(df.Day).sum()
variable.plot(kind='bar',figsize=(10,5),fontsize=8)
plt.xlabel('types of PLU sold')
plt.ylabel('year')
plt.show()

# %%
# Almost every day 4225 sale is high, sale of 4770 is very very less and 4046 has good avg.sale

# %%
variable=df[['Small Bags','Large Bags','XLarge Bags']].groupby(df.year).sum()
variable.plot(kind='bar',figsize=(10,5),fontsize=8)
plt.xlabel('types of Bags')
plt.ylabel('year')
plt.show()

# %%
# small bag sale every year is more than large bag

# %%
corr=df.corr()
corr.shape
# Out:
# (12, 12)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr,annot=True)
plt.show()

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# Day               0.027386     -0.009747 -0.010159 -0.012393 -0.009009
# Month             0.162409     -0.024689 -0.025803 -0.022108 -0.033424
#
# ...

# %%
corr['AveragePrice'].sort_values()
# Out:
# 4046           -0.208317
# Total Volume   -0.192752
# 4770           -0.179446
# Total Bags     -0.177088
# Small Bags     -0.174730
# Large Bags     -0.172940
# 4225           -0.172928
# XLarge Bags    -0.117592
# Day             0.027386
# year            0.093197
# Month           0.162409
# AveragePrice    1.000000
# Name: AveragePrice, dtype: float64

# %%
corr['Total Volume'].sort_values(ascending=False)
# Out:
# Total Volume    1.000000
# 4046            0.977863
# 4225            0.974181
# Small Bags      0.967238
# Total Bags      0.963047
# Large Bags      0.880640
# 4770            0.872202
# XLarge Bags     0.747157
# year            0.017193
# Day            -0.009747
# Month          -0.024689
# AveragePrice   -0.192752
# Name: Total Volume, dtype: float64

# %% [raw]
# # correlation between target variable and feature are less
# # multicollinearity exist.There is strong relationship between total volume and 4046,
#   4225,small bags,total bags,large bags,4770,xlarge bags

# %%
df.shape
# Out:
# (18249, 14)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
cat_col=['type','region']
for i in cat_col:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Day  Month
# 0     8603.62       93.25          0.0     0  2015       0   27     12
# 1     9408.07       97.49          0.0     0  2015       0   20     12
# 2     8042.21      103.14          0.0     0  2015       0   13     12
# 3     5677.40      133.76          0.0     0  2015       0    6     12
# 4     5986.26      197.69          0.0     0  2015       0   29     11

# %%
df['type'].value_counts()
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %%
df['region'].value_counts()
# Out:
# 0     338
# 27    338
# 39    338
# 8     338
# 24    338
# 40    338
# 9     338
# 25    338
# 41    338
# 10    338
# 26    338
# 42    338
# 11    338
# 43    338
# 16    338
# 12    338
# 28    338
# 44    338
# 13    338
# 29    338
# 45    338
# 14    338
# 30    338
# 46    338
# 15    338
# 31    338
# 23    338
# 7     338
# 38    338
# 22    338
# 32    338
# 48    338
# 1     338
# 17    338
# 33    338
# 49    338
# 2     338
# 18    338
# 34    338
# 50    338
# 3     338
# 19    338
# 35    338
# 51    338
# 4     338
# 20    338
# 36    338
# 52    338
# 5     338
# 21    338
# 37    338
# 6     338
# 47    338
# 53    335
# Name: region, dtype: int64

# %%
df=df.drop(columns='Day',axis=1)

# %%
corr=df.corr()
plt.figure(figsize=(20,20))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# ...

# %%
corr['AveragePrice'].sort_values(ascending=False)
# Out:
# AveragePrice    1.000000
# type            0.615845
# Month           0.162409
# year            0.093197
# region         -0.011716
# XLarge Bags    -0.117592
# 4225           -0.172928
# Large Bags     -0.172940
# Small Bags     -0.174730
# Total Bags     -0.177088
# 4770           -0.179446
# Total Volume   -0.192752
# 4046           -0.208317
# Name: AveragePrice, dtype: float64

# %%
#checking skewness

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# Month            0.106617
# dtype: float64

# %%
# We will power transform and check skewness

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in df:
    if plotnumber<=14:
        ax=plt.subplot(3,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
from sklearn.preprocessing import power_transform

# %%
x=df.drop(columns='AveragePrice',axis=1)
y=df['AveragePrice']

# %%
df1=power_transform(x)

# %%
type(df1)
# Out:
# numpy.ndarray

# %%
df1=pd.DataFrame(df1,columns=x.columns)

# %%
df1
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.086605 -0.658619  0.307313 -0.247250   -0.524004   -0.340627
# 1         -0.155746 -0.776870  0.231647 -0.201041   -0.485890   -0.306425
# 2          0.179327 -0.731947  0.579503 -0.007072   -0.552018   -0.366303
# 3          0.003876 -0.634200  0.415100 -0.148322   -0.695449   -0.496853
# 4         -0.187640 -0.685293  0.224806 -0.137918   -0.669157   -0.477201
# ...             ...       ...       ...       ...         ...         ...
# 18244     -0.674587 -0.467366 -0.919470 -1.238310   -0.334466   -0.178839
# 18245     -0.767550 -0.619883 -0.665372 -1.238310   -0.496897   -0.325977
# 18246     -0.771505 -0.619831 -0.772496  0.401546   -0.490952   -0.308728
# 18247     -0.698077 -0.550282 -0.710543  0.401246   -0.424252   -0.248932
# 18248     -0.663809 -0.367908 -0.785173  0.122919   -0.384961   -0.212590
#
#        Large Bags  XLarge Bags      type      year    region     Month
# ...

# %%
df1.shape
# Out:
# (18249, 12)

# %%
df1.skew().sort_values(ascending=False)
# Out:
# XLarge Bags     0.793520
# year            0.213156
# 4770            0.032184
# Total Volume    0.011171
# Small Bags      0.007058
# type            0.000329
# Total Bags     -0.001626
# 4225           -0.017740
# 4046           -0.022679
# Large Bags     -0.073809
# Month          -0.146584
# region         -0.261443
# dtype: float64

# %%
x.shape,y.shape
# Out:
# ((18249, 12), (18249,))

# %%
#Checking Outliers

# %%
from scipy.stats import zscore

# %%
(np.abs(zscore(x))<3).all()
# Out:
# False

# %%
plt.figure(figsize=(20,20))
plotnumber=1

for column in x:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
z_score=zscore(df[['XLarge Bags','4225','4770','4046','Total Bags','Large Bags','Small Bags']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (17782, 13)

# %%
# Regression problem using AveragePrice as class

# %%
x=df.drop(columns=['AveragePrice'],axis=1)
y=df['AveragePrice']

# %%
x.shape,y.shape
# Out:
# ((17782, 12), (17782,))

# %%
(np.abs(zscore(x))<3).all()
# Out:
# False

# %%
z_score=zscore(df[['XLarge Bags','4225','4770','4046','Total Bags','Large Bags','Small Bags']])
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]

# %%
df.shape
# Out:
# (16449, 13)

# %%
x=df.drop(columns=['AveragePrice'],axis=1)
y=df['AveragePrice']

# %%
x.shape,y.shape
# Out:
# ((16449, 12), (16449,))

# %%
(np.abs(zscore(x))<3).all(axis=1)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
data_loss=(18249-16449)/18249*100

# %%
data_loss
# Out:
# 9.863554167351635

# %%
#skewness and outliers are removed

# %%
#checking multicolinearity problem

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled.shape[1]
# Out:
# 10

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range (x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif     features
# 0  1.750522         4046
# 1  2.169883         4225
# 2  1.421103         4770
# 3  2.365585   Small Bags
# 4  1.375165   Large Bags
# 5  1.220346  XLarge Bags
# 6  1.572272         type
# 7  1.153890         year
# 8  1.034782       region
# 9  1.037856        Month

# %%
# VIF value is more than 5 so we drop total volume column

# %%
x=x.drop('Total Volume',axis=1)

# %%
x_scaled=scaler.fit_transform(x)
x_scaled.shape[1]
# Out:
# 11

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range (x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#              vif     features
# 0   1.750537e+00         4046
# 1   2.170570e+00         4225
# 2   1.421106e+00         4770
# 3   3.045030e+12   Total Bags
# 4   2.085000e+12   Small Bags
# 5   2.834681e+11   Large Bags
# 6   8.587493e+08  XLarge Bags
# 7   1.572274e+00         type
# 8   1.154080e+00         year
# 9   1.034787e+00       region
# 10  1.038331e+00        Month

# %%
x=x.drop('Total Bags',axis=1)

# %%
x_scaled=scaler.fit_transform(x)
x_scaled.shape[1]
# Out:
# 10

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range (x_scaled.shape[1])]
vif['features']=x.columns
vif
# Out:
#         vif     features
# 0  1.750522         4046
# 1  2.169883         4225
# 2  1.421103         4770
# 3  2.365585   Small Bags
# 4  1.375165   Large Bags
# 5  1.220346  XLarge Bags
# 6  1.572272         type
# 7  1.153890         year
# 8  1.034782       region
# 9  1.037856        Month

# %%
# All VIF values are less than 5 so there is no multi collinearity problem exist

# %%
# now the dataset  is ready for training

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=121)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((12336, 10), (12336,), (4113, 10), (4113,))

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# By Linear Regression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
y_pred_lr=lr.predict(x_test)

# %%
# comparing actual values with predicted values
Actual_vs_Pred=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_lr})
Actual_vs_Pred.sample(10)
# Out:
#        Actual  Predicted
# 13354    1.49   1.696536
# 2025     1.18   1.032270
# 17963    1.64   1.714456
# 16963    1.73   1.623490
# 17006    2.59   1.687987
# 511      0.89   1.111719
# 12649    0.95   1.562016
# 9966     2.02   1.688246
# 6753     1.22   1.132444
# 15899    1.15   1.623717

# %%
plt.scatter(y_test,y_pred_lr)
plt.xlabel('Actual Average price')
plt.ylabel('Predicted Average price')
plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import statsmodels.formula.api as smf

# %%
print('Mean absolute error :',(metrics.mean_absolute_error(y_test,y_pred_lr)))
print('Mean squared error :',(metrics.mean_squared_error(y_test,y_pred_lr)))
print('Root mean squared error :',(np.sqrt(mean_squared_error(y_test,y_pred_lr))))
print('R2 value is :',(r2_score(y_test,y_pred_lr)))
# Out:
# Mean absolute error : 0.22590218486349034
# Mean squared error : 0.08649748616779357
# Root mean squared error : 0.2941045497230425
# R2 value is : 0.43697935847323943

# %%
# Support Vector Regressor

# %%
svr=SVR()
svr.fit(x_train,y_train)
y_pred_svr=svr.predict(x_test)

# %%
svr.score(x_test,y_test)
# Out:
# 0.6430578772805587

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_pred_svr))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_svr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred_svr)))
# Out:
# MAE: 0.16875537205512914
# MSE: 0.05483741455536007
# RMSE: 0.2341738981085639

# %%
#using Decisiontree regressor

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_test,y_test)
# Out:
# 0.7310884644271127

# %%
y_pred_dt=dt.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_pred_dt))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_dt))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred_dt)))
# Out:
# MAE: 0.13211038171650863
# MSE: 0.04131317772915147
# RMSE: 0.20325643342623

# %%
#using KNN
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_test,y_test)
# Out:
# 0.7573436697418123

# %%
y_pred_knn=knn.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_pred_knn))
print('MSE:', metrics.mean_squared_error(y_test,y_pred_knn))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred_knn)))
# Out:
# MAE: 0.1360753707755896
# MSE: 0.037279561390712375
# RMSE: 0.1930791583540605

# %%
#using random forest regressor
rfc=RandomForestRegressor()
rfc.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfc.score(x_test,y_test)
# Out:
# 0.8872278248516272

# %%
y_pred_rfc=rfc.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,y_pred_rfc))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_rfc))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,y_pred_rfc)))
# Out:
# MAE: 0.0948401167031364
# MSE: 0.017325314456601022
# RMSE: 0.1316256603273124

# %%
# Random Forest gives 89% accuracy
# Decision Tree gives 73% accuracy
# KNN gives 76% accuracy
# SVR gives 64% accuracy
# Linear Regressor gives 45% accuracy

# Here Random Forest gives better accuracy than other regressor

# %%
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(svr,x_scaled,y,cv=5)
# Out:
# array([-0.48077893,  0.35954371,  0.27250242,  0.06530054,  0.12700514])

# %%
cross_val_score(svr,x_scaled,y,cv=5).mean()
# Out:
# 0.06871457504754228

# %%
cross_val_score(dt,x_scaled,y,cv=5)
# Out:
# array([-0.99482942, -0.14602129, -0.05702899, -0.08663171, -0.51058181])

# %%
cross_val_score(dt,x_scaled,y,cv=5).mean()
# Out:
# -0.382830673260085

# %%
cross_val_score(rfc,x_scaled,y,cv=5)
# Out:
# array([-0.17803784,  0.360665  ,  0.48106675,  0.42805598,  0.14509855])

# %%
cross_val_score(rfc,x_scaled,y,cv=5).mean()
# Out:
# 0.24011670641557967

# %%
cross_val_score(knn,x_scaled,y,cv=5)
# Out:
# array([-0.77948518,  0.18621949,  0.21690694, -0.1153972 , -0.26291972])

# %%
cross_val_score(knn,x_scaled,y,cv=5).mean()
# Out:
# -0.15093513413692286

# %%
# Regularization

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10,100],'random_state':list(range(0,15))}

# %%
ls=Lasso()

# %%
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
clf.best_params_
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.001,random_state=0)

# %%
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.001, random_state=0)

# %%
ls.score(x_train,y_train)
# Out:
# 0.4482482051826153

# %%
pred_ls=ls.predict(x_test)

# %%
lss=r2_score(y_test,pred_ls)

# %%
lss
# Out:
# 0.4371792792478223

# %%
# In Linear regression after regularization we get 44% accuracy

# %%
# Hypertuning - GridSearchCV(using Random Forest Regressor )

# %%
parameters={"criterion":['mse','mae'],
            "max_features" :['auto','sqrt','log2'],
            }

# %%
rfc=RandomForestRegressor()

# %%
grid_search=GridSearchCV(rfc,parameters)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
best_parameters=grid_search.best_params_

# %%
best_parameters
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
clf=RandomForestRegressor(criterion='mse' ,max_features='sqrt')

# %%
clf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='mse', max_features='sqrt')

# %%
y_pred=clf.predict(x_test)

# %%
plt.scatter(y_test,y_pred)

# %%
print(r2_score(y_test,y_pred)*100)
print(cross_val_score(rfc,x_scaled,y,cv=5).mean())
# Out:
# 88.93143294520304
# 0.24413892904151613

# %%
# Hypertuning - GridSearchCV(using DecisionTree Regressor )

# %%
grid_search=GridSearchCV(dt,parameters)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
best_param=grid_search.best_params_

# %%
best_param
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
clf=DecisionTreeRegressor(criterion= 'mse', max_features= 'auto')

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_features='auto')

# %%
y_pred_dt=clf.predict(x_test)

# %%
plt.scatter(y_test,y_pred)

# %%
print(r2_score(y_test,y_pred_dt)*100)
print(cross_val_score(dt,x_scaled,y,cv=5).mean())
# Out:
# 74.05935204431361
# -0.38212084203701685

# %% [raw]
# Choosing Best model:
# 1. We get good accuracy about 90% with Random forest. and CV score in Random Forest Regressor is also good.
# 2. MAE: 0.0948401167031364
#    MSE: 0.017325314456601022
#    RMSE: 0.1316256603273124
#
# 3.In regression problem Random Forest works as best model

# %%
# Saving model
import joblib
joblib.dump(grid_search.best_params_,'Avacado_Reg.pkl')
# Out:
# ['Avacado_Reg.pkl']

# %%
#  Classification Problem by using 'region' as class

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Day  Month
# 0     8603.62       93.25          0.0     0  2015       0   27     12
# 1     9408.07       97.49          0.0     0  2015       0   20     12
# 2     8042.21      103.14          0.0     0  2015       0   13     12
# 3     5677.40      133.76          0.0     0  2015       0    6     12
# 4     5986.26      197.69          0.0     0  2015       0   29     11

# %%
x_c=df.drop(columns='region',axis=1)
y_c=df['region']

# %%
scaler=StandardScaler()
x_scaler=scaler.fit_transform(x_c)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaler,y_c,test_size=0.25,random_state=441)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((13686, 13), (13686,), (4563, 13), (4563,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# LOGISTIC REGRESSION
LR=LogisticRegression()
LR.fit(x_train,y_train)
y_pred_LR=LR.predict(x_test)
acc_LR=accuracy_score(y_test,y_pred_LR)*100
acc_LR
# Out:
# 32.193732193732195

# %%
print(confusion_matrix(y_test,y_pred_LR))
print(classification_report(y_test,y_pred_LR))
# Out:
# [[36  0  0 ...  0  0  0]
#  [ 3 23  0 ...  0  0  0]
#  [ 1  0 26 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 92  1  0]
#  [ 0  0  0 ...  1 49  0]
#  [ 0  0  0 ...  0  0 16]]
#               precision    recall  f1-score   support
#
#            0       0.18      0.46      0.26        79
#            1       0.39      0.27      0.32        85
#            2       0.68      0.29      0.41        89
#            3       0.11      0.36      0.17        77
#            4       0.36      0.23      0.28        82
#            5       0.39      0.11      0.17        85
#            6       0.61      0.65      0.63        66
#            7       0.19      0.43      0.27        74
#            8       0.20      0.57      0.30        72
#            9       0.37      0.41      0.39        82
#           10       0.12      0.11      0.11        94
#           11       0.24      0.46      0.31        80
#           12       0.20      0.42      0.27        67
# ...

# %%
# SUPPORT VECTOR CLASSIFIER
from sklearn.svm import SVC 
svc=SVC()
svc.fit(x_train,y_train)
y_pred_svc=svc.predict(x_test)
acc_svc=accuracy_score(y_test,y_pred_svc)*100
acc_svc
# Out:
# 22.92351523120754

# %%
print(confusion_matrix(y_test,y_pred_svc))
print(classification_report(y_test,y_pred_svc))
# Out:
# [[12  0  0 ...  0  0  0]
#  [ 2  5  0 ...  0  0  4]
#  [ 5  0 15 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 87  1  0]
#  [ 0  0  0 ...  0 51  0]
#  [ 0  5  0 ...  0  0 18]]
#               precision    recall  f1-score   support
#
#            0       0.04      0.15      0.07        79
#            1       0.14      0.06      0.08        85
#            2       0.68      0.17      0.27        89
#            3       0.08      0.03      0.04        77
#            4       0.18      0.24      0.21        82
#            5       0.06      0.18      0.08        85
#            6       0.54      0.47      0.50        66
#            7       0.12      0.23      0.16        74
#            8       0.21      0.50      0.29        72
#            9       0.32      0.18      0.23        82
#           10       0.17      0.02      0.04        94
#           11       0.21      0.33      0.26        80
#           12       0.69      0.36      0.47        67
# ...

# %%
# DECISIONTREE CLASSIFIER

DT=DecisionTreeClassifier()
DT.fit(x_train,y_train)
y_pred_DT=DT.predict(x_test)
acc_DT=accuracy_score(y_test,y_pred_DT)*100
acc_DT
# Out:
# 79.53101030024106

# %%
print(confusion_matrix(y_test,y_pred_DT))
print(classification_report(y_test,y_pred_DT))
# Out:
# [[64  0  0 ...  0  0  0]
#  [ 0 68  0 ...  0  0  0]
#  [ 0  0 77 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 96  0  0]
#  [ 0  0  0 ...  1 85  0]
#  [ 0  2  1 ...  0  0 53]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79        79
#            1       0.74      0.80      0.77        85
#            2       0.92      0.87      0.89        89
#            3       0.76      0.82      0.79        77
#            4       0.86      0.90      0.88        82
#            5       0.75      0.75      0.75        85
#            6       0.91      0.91      0.91        66
#            7       0.75      0.89      0.81        74
#            8       0.85      0.96      0.90        72
#            9       0.79      0.77      0.78        82
#           10       0.70      0.79      0.74        94
#           11       0.88      0.75      0.81        80
#           12       0.86      0.85      0.86        67
# ...

# %%
# RANDOM FOREST CLASSIFIER

Rfc=RandomForestClassifier()
Rfc.fit(x_train,y_train)
y_pred_Rfc=Rfc.predict(x_test)
acc_Rfc=accuracy_score(y_test,y_pred_Rfc)*100
acc_Rfc
# Out:
# 90.77361385053693

# %%
print(confusion_matrix(y_test,y_pred_Rfc))
print(classification_report(y_test,y_pred_Rfc))
# Out:
# [[75  0  0 ...  0  0  0]
#  [ 0 71  0 ...  0  0  0]
#  [ 0  0 85 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 96  0  0]
#  [ 0  0  0 ...  2 91  0]
#  [ 0  1  1 ...  0  0 68]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91        79
#            1       0.87      0.84      0.85        85
#            2       0.98      0.96      0.97        89
#            3       0.89      0.86      0.87        77
#            4       0.94      0.93      0.93        82
#            5       0.91      0.87      0.89        85
#            6       0.97      1.00      0.99        66
#            7       0.94      0.92      0.93        74
#            8       0.93      0.96      0.95        72
#            9       0.91      0.89      0.90        82
#           10       0.88      0.85      0.86        94
#           11       0.93      0.95      0.94        80
#           12       0.91      0.96      0.93        67
# ...

# %%
# KNN CLASSIFIER

KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
y_pred_KNN=KNN.predict(x_test)
acc_KNN=accuracy_score(y_test,y_pred_KNN)*100
acc_KNN
# Out:
# 14.639491562568486

# %%
print(confusion_matrix(y_test,y_pred_KNN))
print(classification_report(y_test,y_pred_KNN))
# Out:
# [[60  2  0 ...  0  0  0]
#  [ 3 47  0 ...  0  0  0]
#  [ 1  0 47 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 16  0  0]
#  [ 0  0  0 ...  0 26  0]
#  [ 4  3  1 ...  0  0 18]]
#               precision    recall  f1-score   support
#
#            0       0.36      0.71      0.48        84
#            1       0.33      0.59      0.43        80
#            2       0.47      0.73      0.57        64
#            3       0.41      0.60      0.48        72
#            4       0.54      0.66      0.60        80
#            5       0.55      0.60      0.57        82
#            6       0.90      0.93      0.92        41
#            7       0.51      0.67      0.57        72
#            8       0.69      0.63      0.66        43
#            9       0.35      0.45      0.39        67
#           10       0.34      0.53      0.41        77
#           11       0.37      0.51      0.43        43
#           12       0.80      0.55      0.65        58
# ...

# %%
# XG Boost
from xgboost import XGBClassifier
xgb=XGBClassifier(objective='binary:logistic')
xgb.fit(x_train,y_train)
y_pred_xgb=xgb.predict(x_test)
acc_xgb=accuracy_score(y_test,y_pred_xgb)*100
acc_xgb
# Out:
# [10:17:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 88.143765066842

# %%
print(confusion_matrix(y_test,y_pred_xgb))
print(classification_report(y_test,y_pred_xgb))
# Out:
# [[72  0  0 ...  0  0  0]
#  [ 0 69  0 ...  0  0  0]
#  [ 0  0 83 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 96  0  0]
#  [ 0  0  0 ...  2 88  0]
#  [ 0  1  1 ...  0  0 66]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91        79
#            1       0.86      0.81      0.84        85
#            2       0.99      0.93      0.96        89
#            3       0.87      0.86      0.86        77
#            4       0.92      0.94      0.93        82
#            5       0.87      0.85      0.86        85
#            6       0.97      0.98      0.98        66
#            7       0.89      0.91      0.90        74
#            8       0.93      0.93      0.93        72
#            9       0.84      0.87      0.85        82
#           10       0.82      0.87      0.85        94
#           11       0.95      0.90      0.92        80
#           12       0.96      0.96      0.96        67
# ...

# %%
# Model Evaluation

Models=pd.DataFrame({'model':['Logistic Regression','Support Vector Classifier',
                            'DecisionTree Classifier','Random Forest Classifier','Kneighbors Clasifier','XGBoost'],
                    
                      'score':[acc_LR,acc_svc,acc_DT,acc_Rfc,acc_KNN,acc_xgb]})
Models
# Out:
#                        model      score
# 0        Logistic Regression  32.193732
# 1  Support Vector Classifier  22.923515
# 2    DecisionTree Classifier  79.531010
# 3   Random Forest Classifier  90.773614
# 4       Kneighbors Clasifier  14.639492
# 5                    XGBoost  88.143765

# %% [raw]
# We got our best model i.e. Random forest with the accuracy score of 89%

# %%
# Cross Validation

# %%
# now check for cross validation score as well as overfitting if exist

# %%
# Cross-Validation Logistic Regression
cvs_LR=cross_val_score(LR,x_c,y_c,cv=5)
print(cvs_LR.mean())
# Out:
# 0.11008265728647744

# %%
# Cross-Validation SVC
cvs_svc=cross_val_score(svc,x_c,y_c,cv=5)
print(cvs_svc.mean())
# Out:
# 0.1797270485064401

# %%
# Cross-Validation DecisionTree Classifier
cvs_DT=cross_val_score(DT,x_c,y_c,cv=5)
print(cvs_DT.mean())
# Out:
# 0.5455005349560961

# %%
# Cross-Validation KNN
cvs_KNN=cross_val_score(KNN,x_c,y_c,cv=5)
print(cvs_KNN.mean())
# Out:
# 0.44571211478468487

# %%
# Cross-Validation Random Forest Classifier
cvs_Rfc=cross_val_score(Rfc,x_c,y_c,cv=10)
print(cvs_Rfc.mean())
# Out:
# 0.7711099495313627

# %%
# Cross-Validation XGB Classifier
cvs_xgb=cross_val_score(xgb,x_c,y_c,cv=5)
print(cvs_xgb.mean())
# Out:
# [10:23:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:24:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:24:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
# Cross-Validation: Random Forst gives 77% accuracy

# %%
## hypertuning the model with GridSearchCV (using xgb)

# %%
param_grid={'learning_rate':[1,0.5,0.1,0.01],
            'max_depth':[3,5,7,9,11],
            'n_estimators':[10,20,30,40,100,200]
           }

# %%
grid=GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid)

# %%
grid.fit(x_train,y_train)
# Out:
# [10:33:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:33:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:33:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
best_parameter=grid.best_params_

# %%
best_parameter
# Out:
# {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 200}

# %%
clf=XGBClassifier(learning_rate= 0.1, max_depth= 9, n_estimators= 200)

# %%
clf.fit(x_train,y_train)
# Out:
# [13:48:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=9, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
# ...

# %%
y_pred=clf.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred)*100)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# 89.52443567828183
# [[76  0  0 ...  0  0  0]
#  [ 0 67  0 ...  0  0  0]
#  [ 0  0 83 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 96  0  0]
#  [ 0  0  0 ...  1 87  0]
#  [ 0  1  2 ...  0  0 66]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94        79
#            1       0.91      0.79      0.84        85
#            2       0.97      0.93      0.95        89
#            3       0.89      0.87      0.88        77
#            4       0.93      0.93      0.93        82
#            5       0.93      0.91      0.92        85
#            6       0.95      0.95      0.95        66
#            7       0.95      0.95      0.95        74
#            8       0.91      0.94      0.93        72
#            9       0.87      0.84      0.86        82
#           10       0.80      0.85      0.82        94
#           11       0.95      0.91      0.93        80
#           12       0.93      0.94      0.93        67
# ...

# %%
# XGBoost give accuracy 89.5% after tunning.

# %%
from sklearn.metrics import plot_roc_curve
from sklearn import datasets 
from sklearn import metrics

# %%
x,y=datasets.make_classification(random_state=441)
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=441)
ds=RandomForestClassifier(random_state=441)
ds.fit(x_train,y_train)
metrics.plot_roc_curve(ds,x_test,y_test)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x,y=datasets.make_classification(random_state=441)
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=441)
ds1=XGBClassifier(random_state=441)
ds1.fit(x_train,y_train)
metrics.plot_roc_curve(ds1,x_test,y_test)
plt.show
# Out:
# [16:03:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Saving model
import joblib
joblib.dump(Rfc,'Avacado_class.pkl')
# Out:
# ['Avacado_class.pkl']

# %% [raw]
# Conclusion:
# Here Random Forest and XGBoost,Decision Tree,knn all works good.
# By comparing the different model in this classification problem we can conclude that
# Random forest works best here.
# we choose Random Forest best model here because we get accuracy score 90%
# Cross-validation is 77% and AUC value is 94%
